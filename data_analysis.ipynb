# %% [markdown]
# # Taiwan Social Change Survey (TSCS) Data Analysis
# ## 1992-2022 Time Series Analysis
#
# This notebook imports and analyzes TSCS data from 1992 to 2022 (every 5 years) to identify common variables **by their meaning (labels)** across all survey years for time-series visualization.
#
# **Important**: Variables may have different names (e.g., v_26 vs v_32) across years, but if they measure the same concept (e.g., "subjective wealth"), they are considered common variables.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import pyreadstat
from pathlib import Path
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Load TSCS Data Files
#
# Loading all SPSS (.sav) files from the vi_data directory with metadata.

# %%
# Define data path and file mappings
data_path = Path('../vi_data')

# Map files to years
data_files = {
    1992: 'tscs921.sav',
    1997: 'tscs971_l.sav',
    2002: 'tscs021.sav',
    2007: 'tscs071.sav',
    2012: 'tscs121.sav',
    2017: 'tscs171.sav',
    2022: 'tscs221.sav'
}

# Dictionary to store dataframes and metadata
datasets = {}
metadata = {}

# Load each dataset
for year, filename in data_files.items():
    file_path = data_path / filename
    try:
        df, meta = pyreadstat.read_sav(str(file_path))
        datasets[year] = df
        metadata[year] = meta
        print(f"✓ Loaded {year}: {len(df)} records, {len(df.columns)} variables")
    except Exception as e:
        print(f"✗ Error loading {year}: {e}")

print(f"\nTotal datasets loaded: {len(datasets)}")
# Out:
# ✓ Loaded 1992: 2377 records, 572 variables
# ✓ Loaded 1997: 2596 records, 495 variables
# ✓ Loaded 2002: 1992 records, 631 variables
# ✓ Loaded 2007: 2040 records, 739 variables
# ✓ Loaded 2012: 2134 records, 432 variables
# ✓ Loaded 2017: 1917 records, 990 variables
# ✓ Loaded 2022: 1739 records, 446 variables
#
# Total datasets loaded: 7

# %% [markdown]
# ## Extract Variable Labels for Each Year
#
# Build mappings of variable names to their labels (meanings) for each survey year.

# %%
# Extract variable labels for each year
year_labels = {}  # {year: {var_name: label}}
label_to_vars = {} # {year: {label: var_name}}

for year in sorted(datasets.keys()):
    year_labels[year] = {}
    label_to_vars[year] = {}
    
    col_to_label = metadata[year].column_names_to_labels
    
    for var_name in datasets[year].columns:
        label = col_to_label.get(var_name, None)
        if label:
            # Clean up label (strip whitespace)
            label = label.strip()
            year_labels[year][var_name] = label
            label_to_vars[year][label] = var_name
    
    print(f"{year}: {len(year_labels[year])} variables with labels")
# Out:
# 1992: 572 variables with labels
# 1997: 495 variables with labels
# 2002: 631 variables with labels
# 2007: 739 variables with labels
# 2012: 432 variables with labels
# 2017: 990 variables with labels
# 2022: 446 variables with labels

# %% [markdown]
# ## Display Sample Labels from Each Year

# %%
# Show sample of labels from each year
for year in sorted(datasets.keys()):
    if year == 2017:
        print(f"\n{'='*70}")
        print(f"Year {year} - Sample Variable Labels:")
        print(f"{'='*70}")

        for i, (var, label) in enumerate(list(year_labels[year].items())):
            print(f"{var:15s} -> {label}")
# Out:
# ======================================================================
# Year 2017 - Sample Variable Labels:
# ======================================================================
# id              -> id 受訪者編號
# zip             -> zip (抽樣地區)郵遞區號
# stratum2        -> stratum2 2005層別代碼
# region          -> region 2005地理區代碼
# stratum2014     -> stratum2014 2014層別代碼
# region2014      -> region2014 2014地理區代碼
# r_stratum2014   -> r_stratum201 2014地理區與層別代碼
# psu             -> psu 第一抽出單位
# ssu             -> ssu 第二抽出單位
# wsel0           -> wsel0 不等機率加權權值(抽樣)
# wsel            -> wsel 不等機率加權權值
# wr_19_4         -> wr_19_4 建立在初始權值等於不等機率加權權值，且以19分層及教育程度4分類進行加權之多變項反覆加權權值
# wr_19_5         -> wr_19_5 建立在初始權值等於不等機率加權權值，且以19分層及教育程度5分類進行加權之多變項反覆
# wave            -> wave 波次
# qtype           -> qtype 問卷別
# year            -> year 調查年(西元年)
# year_m          -> year_m 調查年(民國年)
# sdt1            -> sdt 訪問開始日期
# sdt2            -> sdt 訪問開始時間【24小時制】
# a1              -> A1 性別
# a2y             -> A2 請問您是什麼時候出生的?出生年
# a2m             -> A2 請問您是什麼時候出生的?出生月
# a2a             -> A2a 請問您大約幾歲?
# a3city          -> A3 請問您在什麼地方出生的?
# ka3city         -> A3 請問您在什麼地方出生的?(29)其他
# a3zip           -> A3 請問您在什麼地方出生的?
# a4city          -> A4 請問您15歲以前住得最久的地方是哪裡?
# ka4city         -> A4 請問您15歲以前住得最久的地方是哪裡?(29)其他
# a4zip           -> A4 請問您15歲以前住得最久的地方是哪裡?郵遞區號
# a5              -> A5 請問您現在居住在哪裡?
# a5city          -> A5a 請問您的現住地地址:縣市
# ka5city         -> A5a 請問您的現住地地址(29)其他
# a5zip           -> A5a 請問您的現住地地址?郵遞區號
# a6              -> A6 請問您父親是哪裡人?
# ka6             -> A6 請問您父親是哪裡人?(07)其他,請說明
# a7              -> A7 請問您母親是哪裡人?
# ka7             -> A7 請問您母親是哪裡人?(07)其他,請說明
# a8              -> A8 請問您6歲時在家裡最常講哪一種語言呢?
# ka8             -> A8 請問您6歲時在家裡最常講哪一種語言呢?(08)其他,請說明
# a9              -> A9 請問您國(初)中畢業或15歲時在家裡最常講哪一種語言呢?
# ka9             -> A9 請問您國(初)中畢業或15歲時在家裡最常講哪一種語言呢?(08)其他,請說明
# a10             -> A10 請問您目前的宗教信仰?
# ka10            -> A10 請問您目前的宗教信仰?(10)其他,請說明
# a11             -> A11 請問您目前是否領有台灣普通小型車駕駛執照?
# a12             -> A12 請問您目前參加下列的哪裡?職業身份的社會保險?
# ka12            -> A12 請問您目前參加下列的哪裡?職業身份的社會保險?(08)其他,請說明
# b1              -> B1 請問您的教育程度是
# kb1             -> B1 請問您的教育程度是:(22)其他,請說明
# b2a01           -> B2a01 請問國中畢業後第01個學校您所就讀學校的類別?
# kb2a01          -> B2a01 請問國中畢業後第01個學校您所就讀學校的類別?(22)其他,請說明
# b2b01           -> B2b01 請問國中畢業後第01個學校您有沒有畢業?
# b2t01           -> B2c01 請問國中畢業後第01個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c101          -> B2c01 請問國中畢業後第01個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c201          -> B2c01 請問國中畢業後第01個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d01           -> B2d01 請問國中畢業後第01個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e01city       -> B2e01 請問國中畢業後第01個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e01city      -> B2e01 請問國中畢業後第01個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f01r          -> B2f01 請問國中畢業後第01個學校所就讀科系的全名是?(02)科系類別
# b2f01c          -> B2f01 請問國中畢業後第01個學校所就讀科系的全名是?(04)科系代碼
# b2e01w          -> B2e01 有沒有第2個學校需要填寫?
# b2a02           -> B2a02 請問國中畢業後第02個學校您所就讀學校的類別?
# kb2a02          -> B2a02 請問國中畢業後第02個學校您所就讀學校的類別?(22)其他,請說明
# b2b02           -> B2b02 請問國中畢業後第02個學校您有沒有畢業?
# b2t02           -> B2c02 請問國中畢業後第02個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c102          -> B2c02 請問國中畢業後第02個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c202          -> B2c02 請問國中畢業後第02個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d02           -> B2d02 請問國中畢業後第02個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e02city       -> B2e02 請問國中畢業後第02個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e02city      -> B2e02 請問國中畢業後第02個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f02r          -> B2f02 請問國中畢業後第02個學校所就讀科系的全名是?(02)科系類別
# b2f02c          -> B2f02 請問國中畢業後第02個學校所就讀科系的全名是?(04)科系代碼
# b2e02w          -> B2e02 有沒有第3個學校需要填寫?
# b2a03           -> B2a03 請問國中畢業後第03個學校您所就讀學校的類別?
# kb2a03          -> B2a03 請問國中畢業後第03個學校您所就讀學校的類別(22)其他,請說明
# b2b03           -> B2b03 請問國中畢業後第03個學校您有沒有畢業?
# b2t03           -> B2c03 請問國中畢業後第03個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c103          -> B2c03 請問國中畢業後第03個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c203          -> B2c03 請問國中畢業後第03個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d03           -> B2d03 請問國中畢業後第03個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e03city       -> B2e03 請問國中畢業後第03個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e03city      -> B2e03 請問國中畢業後第03個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f03r          -> B2f03 請問國中畢業後第03個學校所就讀科系的全名是?(02)科系類別
# b2f03c          -> B2f03 請問國中畢業後第03個學校所就讀科系的全名是?(04)科系代碼
# b2e03w          -> B2e03 有沒有第4個學校需要填寫?
# b2a04           -> B2a04 請問國中畢業後第04個學校您所就讀學校的類別?
# kb2a04          -> B2a04 請問國中畢業後第04個學校您所就讀學校的類別(22)其他,請說明
# b2b04           -> B2b04 請問國中畢業後第04個學校您有沒有畢業?
# b2t04           -> B2c04 請問國中畢業後第04個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c104          -> B2c04 請問國中畢業後第04個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c204          -> B2c04 請問國中畢業後第04個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d04           -> B2d04 請問國中畢業後第04個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e04city       -> B2e04 請問國中畢業後第04個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e04city      -> B2e04 請問國中畢業後第04個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f04r          -> B2f04 請問國中畢業後第04個學校所就讀科系的全名是?(02)科系類別
# b2f04c          -> B2f04 請問國中畢業後第04個學校所就讀科系的全名是?(04)科系代碼
# b2e04w          -> B2e04 有沒有第5個學校需要填寫?
# b2a05           -> B2a05 請問國中畢業後第05個學校您所就讀學校的類別?
# kb2a05          -> B2a05 請問國中畢業後第05個學校您所就讀學校的類別(22)其他,請說明
# b2b05           -> B2b05 請問國中畢業後第05個學校您有沒有畢業?
# b2t05           -> B2c05 請問國中畢業後第05個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c105          -> B2c05 請問國中畢業後第05個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c205          -> B2c05 請問國中畢業後第05個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d05           -> B2d05 請問國中畢業後第05個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e05city       -> B2e05 請問國中畢業後第05個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e05city      -> B2e05 請問國中畢業後第05個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f05r          -> B2f05 請問國中畢業後第05個學校所就讀科系的全名是?(02)科系類別
# b2f05c          -> B2f05 請問國中畢業後第05個學校所就讀科系的全名是?(04)科系代碼
# b2e05w          -> B2e05 有沒有第6個學校需要填寫?
# b2a06           -> B2a06 請問國中畢業後第06個學校您所就讀學校的類別?
# kb2a06          -> B2a06 請問國中畢業後第06個學校您所就讀學校的類別(22)其他,請說明
# b2b06           -> B2b06 請問國中畢業後第06個學校您有沒有畢業?
# b2t06           -> B2c06 請問國中畢業後第06個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c106          -> B2c06 請問國中畢業後第06個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c206          -> B2c06 請問國中畢業後第06個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d06           -> B2d06 請問國中畢業後第06個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e06city       -> B2e06 請問國中畢業後第06個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e06city      -> B2e06 請問國中畢業後第06個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f06r          -> B2f06 請問國中畢業後第06個學校所就讀科系的全名是?(02)科系類別
# b2f06c          -> B2f06 請問國中畢業後第06個學校所就讀科系的全名是?(04)科系代碼
# b2e06w          -> B2e06 有沒有第7個學校需要填寫?
# b2a07           -> B2a07 請問國中畢業後第07個學校您所就讀學校的類別?
# kb2a07          -> B2a07 請問國中畢業後第07個學校您所就讀學校的類別(22)其他,請說明
# b2b07           -> B2b07 請問國中畢業後第07個學校您有沒有畢業?
# b2t07           -> B2c07 請問國中畢業後第07個學校您民國幾年到幾年就讀這個學校?(單位)民國年/歲數
# b2c107          -> B2c07 請問國中畢業後第07個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(歲)
# b2c207          -> B2c07 請問國中畢業後第07個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(歲)
# b2d07           -> B2d07 請問國中畢業後第07個學校這個學校是公立還是私立?是日間還是夜間部,或是進修部或專班?
# b2e07city       -> B2e07 請問國中畢業後第07個學校所在的縣市與學校全名是?(01)學校所在的縣市
# kb2e07city      -> B2e07 請問國中畢業後第07個學校所在的縣市與學校全名是?(02)國外學校所在詳細縣市
# b2f07r          -> B2f07 請問國中畢業後第07個學校所就讀科系的全名是?(02)科系類別
# b2f07c          -> B2f07 請問國中畢業後第07個學校所就讀科系的全名是?(04)科系代碼
# b2e07w          -> B2e07 有沒有第8個學校需要填寫?
# b3a             -> B3a 請問您讀小學/國中的時候,有沒有遇到過對您影響很大的好老師?
# b3b01           -> B3b 請問這些好老師影響您的原因是?(01)在您生活或學業上有困難時幫助您
# b3b02           -> B3b 請問這些好老師影響您的原因是?(02)會聽您訴說您的困擾,給您建議,或特別鼓勵您
# b3b03           -> B3b 請問這些好老師影響您的原因是?(03)說的話或做的事對您影響很深
# b3b04           -> B3b 請問這些好老師影響您的原因是?(04)其他
# kb3b04          -> B3b 請問這些好老師影響您的原因是?(04)其他,請說明
# b4              -> B4 請問您目前的婚姻狀況是?
# kb4             -> B4 請問您目前的婚姻狀況是?(08)其他,請說明
# b5t01           -> B5 第1段婚姻經歷(單位)民國年/歲數
# b5s01           -> B5 第1段婚姻經歷(1)開始時間
# b5e01           -> B5 第1段婚姻經歷(2)結束時間
# b5n01           -> B5 第1段婚姻經歷之後有沒有下一段婚姻變化?
# b5c02           -> B5 第2段分居/離婚或結婚(再婚)經歷
# b5t02           -> B5 第2段分居/離婚或結婚(再婚)經歷(單位)民國年/歲數
# b5s02           -> B5 第2段分居/離婚或結婚(再婚)經歷(1)開始時間
# b5e02           -> B5 第2段分居/離婚或結婚(再婚)經歷(2)結束時間時間
# b5n02           -> B5 第2段婚姻經歷之後有沒有下一段婚姻變化?
# b5c03           -> B5 第3段分居/離婚或結婚(再婚)經歷
# b5t03           -> B5 第3段分居/離婚或結婚(再婚)經歷(單位)民國年/歲數
# b5s03           -> B5 第3段分居/離婚或結婚(再婚)經歷(1)開始時間
# b5e03           -> B5 第3段分居/離婚或結婚(再婚)經歷(2)結束時間時間
# b5n03           -> B5 第3段婚姻經歷之後有沒有下一段婚姻變化?
# b5c04           -> B5 第4段分居/離婚或結婚(再婚)經歷
# b5t04           -> B5 第4段分居/離婚或結婚(再婚)經歷(單位)民國年/歲數
# b5s04           -> B5 第4段分居/離婚或結婚(再婚)經歷(1)開始時間
# b5e04           -> B5 第4段分居/離婚或結婚(再婚)經歷(2)結束時間時間
# b5n04           -> B5 第4段婚姻經歷之後有沒有下一段婚姻變化?
# b5c05           -> B5 第5段分居/離婚或結婚(再婚)經歷
# b5t05           -> B5 第5段分居/離婚或結婚(再婚)經歷(單位)民國年/歲數
# b5s05           -> B5 第5段分居/離婚或結婚(再婚)經歷(1)開始時間
# b5e05           -> B5 第5段分居/離婚或結婚(再婚)經歷(2)結束時間時間
# b5n05           -> B5 第5段婚姻經歷之後有沒有下一段婚姻變化?
# b5c06           -> B5 第6段分居/離婚或結婚(再婚)經歷
# b5t06           -> B5 第6段分居/離婚或結婚(再婚)經歷(單位)民國年/歲數
# b5s06           -> B5 第6段分居/離婚或結婚(再婚)經歷(1)開始時間
# b5e06           -> B5 第6段分居/離婚或結婚(再婚)經歷(2)結束時間時間
# b5n06           -> B5 第6段婚姻經歷之後有沒有下一段婚姻變化?
# b7y             -> B7 請問您配偶(或同居伴侶)是什麼時候出生的?(01)民國年
# b7m             -> B7 請問您配偶(或同居伴侶)是什麼時候出生的?(02)月
# b7a             -> B7a 請問您配偶(或同居伴侶)大約幾歲?
# b8              -> B8 請問您配偶(或同居伴侶)的教育程度是
# kb8             -> B8 請問您配偶(或同居伴侶)的教育程度是:(22)其他,請說明
# b9              -> B9 請問您配偶(或同居伴侶)的父親是哪裡人?
# kb9             -> B9 請問您配偶(或同居伴侶)的父親是哪裡人?(07)其他,請說明
# b10             -> B10 請問您配偶(或同居伴侶)的母親是哪裡人?
# kb10            -> B10 請問您配偶(或同居伴侶)的母親是哪裡人?(07)其他,請說明
# b11             -> B11 請問您有沒有小孩?
# b12t01          -> B12 請問您的第1個小孩是在民國幾年出生(單位)民國年/歲數
# b12y01          -> B12 請問您的第1個小孩是在民國幾年出生(01)出生年/歲
# b12s01          -> B12 請問您的第1個小孩是男生還是女生?
# b12n01          -> B12 請問您有沒有第2個小孩?
# b12t02          -> B12 請問您的第2個小孩是在民國幾年出生(單位)民國年/歲數
# b12y02          -> B12 請問您的第2個小孩是在民國幾年出生(01)出生年/歲
# b12s02          -> B12 請問您的第2個小孩是男生還是女生?
# b12n02          -> B12 請問您有沒有第3個小孩?
# b12t03          -> B12 請問您的第3個小孩是在民國幾年出生?(單位)民國年/歲數
# b12y03          -> B12 請問您的第3個小孩是在民國幾年出生?(01)出生年/歲
# b12s03          -> B12 請問您的第3個小孩是男生還是女生?性別
# b12n03          -> B12 請問您有沒有第4個小孩?
# b12t04          -> B12 請問您的第4個小孩是在民國幾年出生?(單位)民國年/歲數
# b12y04          -> B12 請問您的第4個小孩是在民國幾年出生?(01)出生年/歲
# b12s04          -> B12 請問您的第4個小孩是男生還是女生?性別
# b12n04          -> B12 請問您有沒有第5個小孩?
# b12t05          -> B12 請問您的第5個小孩是在民國幾年出生?(單位)民國年/歲數
# b12y05          -> B12 請問您的第5個小孩是在民國幾年出生?(01)出生年/歲
# b12s05          -> B12 請問您的第5個小孩是男生還是女生?性別
# b12n05          -> B12 請問您有沒有第6個小孩?
# b12t06          -> B12 請問您的第6個小孩是在民國幾年出生?(單位)民國年/歲數
# b12y06          -> B12 請問您的第6個小孩是在民國幾年出生?(01)出生年/歲
# b12s06          -> B12 請問您的第6個小孩是男生還是女生?性別
# b12n06          -> B12 請問您有沒有第7個小孩?
# b12t07          -> B12 請問您的第7個小孩是在民國幾年出生?(單位)民國年/歲數
# b12y07          -> B12 請問您的第7個小孩是在民國幾年出生?(01)出生年/歲
# b12s07          -> B12 請問您的第7個小孩是男生還是女生?性別
# b12n07          -> B12 請問您有沒有第8個小孩?
# b13             -> B13 請問您父親的教育程度是
# kb13            -> B13 請問您父親的教育程度是(22)其他,請說明
# b14             -> B14 請問您母親的教育程度是
# kb14            -> B14 請問您母親的教育程度是(22)其他,請說明
# b15             -> B15 請問您父親是什麼時候出生的?(01)民國後或民國前
# b15y            -> B15 請問您父親是什麼時候出生的?(02)出生年/歲
# b16             -> B16 請問您母親是什麼時候出生的?(01)民國後或民國前
# b16y            -> B16 請問您母親是什麼時候出生的?(02)出生年/歲
# b17a            -> B17 請問您們家有幾位兄弟姊妹?a兄
# b17b            -> B17 請問您們家有幾位兄弟姊妹?b弟
# b17c            -> B17 請問您們家有幾位兄弟姊妹?c姊
# b17d            -> B17 請問您們家有幾位兄弟姊妹?d妹
# c1a             -> C1 您國(初)中畢業或15歲時,請問父親還在嗎?
# c1b             -> C1 您國(初)中畢業或15歲時,父親有沒有工作?
# kc2             -> KC2 您國(初)中畢業或15歲時,您父親在做什麼事?
# c2a3            -> C2 您國(初)中畢業或15歲時,您父親在做什麼事?(a3)行業碼
# c2b4            -> C2 您國(初)中畢業或15歲時,您父親在做什麼事?(b4)變遷職業碼
# c2b5            -> C2 您國(初)中畢業或15歲時,您父親在做什麼事?(b5)ISCO08職業碼
# c2b5r           -> C2 您國(初)中畢業或15歲時,您父親在做什麼事?ISCO88職業碼
# c3              -> C3 您國(初)中畢業或15歲時,您父親在哪裡工作?為誰工作?
# c3a             -> C3a 您國(初)中畢業或15歲時,您父親受哪一種固定公司或機構雇用?
# kc3a            -> C3a 您國(初)中畢業或15歲時,您父親受哪一種固定公司或機構雇用?(07)其他,請說明
# c4              -> C4 您國(初)中畢業或15歲時,您父親工作的公司/機構大約雇有多少員工?
# c5              -> C5 您國(初)中畢業或15歲時,您父親的工作有沒有包括管理其他員工?
# c6a             -> C6 您國(初)中畢業或15歲時,請問您母親還在嗎
# c6b             -> C6 您國(初)中畢業或15歲時,您母親有沒有工作?
# kc7             -> KC7 您國(初)中畢業或15歲時,您母親在做什麼事?
# c7a3            -> C7 您國(初)中畢業或15歲時,請問您母親在做什麼事?(a3)行業碼
# c7b4            -> C7 您國(初)中畢業或15歲時,請問您母親在做什麼事?(b4)變遷職業碼
# c7b5            -> C7 您國(初)中畢業或15歲時,請問您母親在做什麼事?(b5)ISCO08職業碼
# c7b5r           -> C7 您國(初)中畢業或15歲時,請問您母親在做什麼事?ISCO88職業碼
# c8              -> C8 您國(初)中畢業或15歲時,您母親在哪裡工作?為誰工作?
# c8a             -> C8a 您國(初)中畢業或15歲時,您母親受哪一種固定公司或機構雇用?
# kc8a            -> C8a 您國(初)中畢業或15歲時,您母親受哪一種固定公司或機構雇用?(07)其他,請說明
# c9              -> C9 您國(初)中畢業或15歲時,您母親工作的公司/機構大約雇有多少員工?
# c10             -> C10 您國(初)中畢業或15歲時,您家庭的經濟狀況,比當時一般家庭的平均生活條件好還是差?
# c11             -> C11 您的配偶目前的工作狀況?
# kc11            -> C11 您的配偶目前的工作狀況?(17)其他,請說明
# c11a            -> C11a 您的配偶有做過工作嗎?
# ck12            -> KC12 您配偶目前主要在做什麼事?
# c12a3           -> C12 您的配偶目前的工作主要在做什麼?(a3)行業碼
# c12b4           -> C12 您的配偶目前的工作主要在做什麼?(b4)變遷職業碼
# c12b5           -> C12 您的配偶目前的工作主要在做什麼?(b5)ISCO08職業碼
# c12b5r          -> C12 您的配偶目前的工作主要在做什麼?ISCO88職業碼
# c13             -> C13 您的配偶目前的工作屬於下列哪一種?
# c14             -> C14 您的配偶目前在哪裡工作?為誰工作?
# c14a            -> C14a 您的配偶目前受哪一種固定公司或機構雇用?
# kc14a           -> C14a 您的配偶目前受哪一種固定公司或機構雇用?(07)其他,請說明
# c15             -> C15 您的配偶目前工作的公司/機構大約雇有多少員工
# c16             -> C16 您的配偶目前平均每週大約工作多少小時?
# c17             -> C17 下列哪一個是您目前的工作狀況?
# kc17            -> C17 下列哪一個是您目前的工作狀況?(17)其他,請說明
# c18             -> C18 您目前的這個工作或職務符合下列哪一個?
# kc18            -> C18 您目前的這個工作或職務符合下列哪一個?(15)其他(請說明)
# c19cid          -> C19_id 受訪者目前工作或職務的公司代號(序號)和職務代號(序號)(01)公司代號(序號)
# c19jid          -> C19_id 受訪者目前工作或職務的公司代號(序號)和職務代號(序號)(02)職務代號(序號)
# c19a3           -> C19 您目前這家公司/機構的名稱和職務為何?(a3)行業碼
# c19b4           -> C19 您目前這家公司/機構的名稱和職務為何?(b4)變遷職業碼
# c19b5           -> C19 您目前這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c19b5r          -> C19 您目前這家公司/機構的名稱和職務為何?ISCO88職業碼
# c20             -> C20 您目前這個公司或機構全體員工約有多少人?
# c21             -> C20 目前您這個工作當時的職務上有沒有管人?
# c22             -> C22 您是怎麼找到目前這個工作或職務?
# kc22            -> C22 您是怎麼找到目前這個工作或職務?(14)其他,請說明
# c23a            -> C23 您目前這個工作每週上班天數
# c23b            -> C23 您目前這個工作每天上班時數
# c23c            -> C23 您目前這個工作每週上班總時數
# c24             -> C24 您目前這個工作平均每月所有工作收入(選項)
# c24a            -> C24 您目前這個工作平均每月所有工作收入(數值)
# c25             -> C25 您為什麼不做了?
# kc25            -> C25 您為什麼不做了?(14)其他,請說明
# c26st           -> C26 您民國幾年幾月開始目前這個工作或職?(單位)民國年/歲數
# c26sy           -> C26 您民國幾年幾月開始目前這個工作或職務?民國年(歲)
# c26sm           -> C26 您民國幾年幾月開始目前這個工作或職務?月份
# c26et           -> C26 您民國幾年幾月結束目前這個工作或職?(單位)民國年/歲數
# c26ey           -> C26 您民國幾年幾月結束目前這個工作或職務?民國年(歲)
# c26em           -> C26 您民國幾年幾月結束目前這個工作或職務?月份
# c27             -> C27 您目前主要的工作屬於下列哪一種?
# c28             -> C28 您目前主要的工作單位裡,您的工作同事多少定期契約人員、臨時人員、人力派遣人員、外包人員?
# c29city         -> C29 您目前的工作地點是哪一個縣市
# kc29city        -> C29 您目前的工作地點是哪一個縣市(29)其他,請說明
# c29zip          -> C29 您目前的工作地點是哪裡?郵遞區號
# c30             -> C30 整體來說,您滿意或不滿意自己目前的工作?
# c31a1           -> C31a1 您結束最後一個工作到現在,有沒有超過三個月以上沒有工作?
# kc31a1          -> C31a1 您結束最後一個工作到現在,有沒有超過三個月以上沒有工作?(15)有,請說明
# c31bst1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,開始時間?(單位)民國年/歲
# c31bsy1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,開始時間?(1)民國年(歲)
# c31bsm1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,開始時間?(2)月份
# c31bet1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,結束時間?(單位)民國年/歲
# c31bey1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,結束時間?(1)民國年(歲)
# c31bem1         -> C31b1 您結束最後一個工作到現在,有超過三個月以上沒有工作,結束時間?(2)月份
# c31a2           -> C31a2 您結束第一個沒有工作的狀態後,還有沒有超過三個月以上沒有工作?
# kc31a2          -> C31a2 您結束第一個沒有工作的狀態後,還有沒有超過三個月以上沒有工作?(15)有,請說明
# c31bst2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(單位)民國年/歲
# c31bsy2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(1)民國年(歲)
# c31bsm2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(2)月份
# c31bet2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(單位)民國年/歲
# c31bey2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(1)民國年(歲)
# c31bem2         -> C31b2 您結束第一個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(2)月份
# c31a3           -> C31a3 您結束第二個沒有工作的狀態後,還有沒有超過三個月以上沒有工作?
# kc31a3          -> C31a3 您結束第二個沒有工作的狀態後,還有沒有超過三個月以上沒有工作?(15)有,請說明
# c31bst3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(單位)民國年/歲
# c31bsy3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(1)民國年(歲)
# c31bsm3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,開始時間?(2)月份
# c31bet3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(單位)民國年/歲
# c31bey3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(1)民國年(歲)
# c31bem3         -> C31b3 您結束第二個沒有工作的狀態後，超過三個月以上沒有工作,結束時間?(2)月份
# c32city         -> C32 請問您第一份工作的工作地點在哪裡?(縣市)
# kc32city        -> C32 請問您第一份工作的工作地點在哪裡?(29)其他,請說明
# c32zip          -> C32 請問您第一份工作的工作地點在哪裡?郵遞區號
# c33             -> C33 請問您第一份工作剛開始做的時候,每個月的收入是多少?(級距)
# c33a            -> C33 請問您第一份工作剛開始做的時候,每個月的收入是多少?(數值)
# c3401cid        -> C34 第1個工作公司代號(序號)
# c3401jid        -> C34 第1個工作職務(序號)
# c3401           -> C34 請問您的第1個工作或職務符合哪一個?
# kc3401          -> C34 請問您的第1個工作或職務符合哪一個?(15)其他,請說明
# c3501a3         -> C35 請問您的第1個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3501b5         -> C35 請問您的第1個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3601           -> C36 請問您的第1個工作這個公司或機構全體員工約有多少人?
# c3701           -> C37 請問您的第1個工作當時的職務上有沒有管人?
# c3801           -> C38 請問您的第1個工作是怎麼找到這個工作或職務?
# kc3801          -> C38 請問您的第1個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3901a          -> C39 請問您的第1個工作或職務每個星期大約工作___天?
# c3901b          -> C39 請問您的第1個工作或職務每天___小時?
# c3901c          -> C39 請問您的第1個工作或職務每個星期大約工作___小時?
# c4001           -> C40 請問您的第1個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4001a          -> C40 請問您的第1個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4101           -> C41 假如第1個不是您現在的工作或職務,請問您為什麼不做了?
# kc4101          -> C41 假如第1個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4201st         -> C42 請問您的第1個工作是民國幾年幾月開?(單位)民國年/歲數
# c4201sy         -> C42 請問您的第1個工作是民國幾年幾月開始?民國年(歲)
# c4201sm         -> C42 請問您的第1個工作是民國幾年幾月開始?月份
# c4201et         -> C42 請問您的第1個工作是民國幾年幾月結?(單位)民國年/歲數
# c4201ey         -> C42 請問您的第1個工作是民國幾年幾月結束?民國年
# c4201em         -> C42 請問您的第1個工作是民國幾年幾月結束?月份
# c4301           -> C43 請問您結束第1個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3402cid        -> C34 第2個工作公司代號(序號)
# c3402jid        -> C34 第2個工作職務(序號)
# c3402           -> C34 請問您的第2個工作或職務符合哪一個?
# kc3402          -> C34 請問您的第2個工作或職務符合哪一個?(15)其他,請說明
# c3502a3         -> C35 請問您的第2個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3502b5         -> C35 請問您的第2個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3602           -> C36 請問您的第2個工作這個公司或機構全體員工約有多少人?
# c3702           -> C37 請問您的第2個工作當時的職務上有沒有管人?
# c3802           -> C38 請問您的第2個工作是怎麼找到這個工作或職務?
# kc3802          -> C38 請問您的第2個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3902a          -> C39 請問您的第2個工作或職務每個星期大約工作___天?
# c3902b          -> C39 請問您的第2個工作或職務每天___小時?
# c3902c          -> C39 請問您的第2個工作或職務每個星期大約工作___小時?
# c4002           -> C40 請問您的第2個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4002a          -> C40 請問您的第2個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4102           -> C41 假如第2個不是您現在的工作或職務,請問您為什麼不做了?
# kc4102          -> C41 假如第2個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4202st         -> C42 請問您的第2個工作是民國幾年幾月開?(單位)民國年/歲數
# c4202sy         -> C42 請問您的第2個工作是民國幾年幾月開始?民國年(歲)
# c4202sm         -> C42 請問您的第2個工作是民國幾年幾月開始?月份
# c4202et         -> C42 請問您的第2個工作是民國幾年幾月結?(單位)民國年/歲數
# c4202ey         -> C42 請問您的第2個工作是民國幾年幾月結束?民國年
# c4202em         -> C42 請問您的第2個工作是民國幾年幾月結束?月份
# c4302           -> C43 請問您結束第2個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3403cid        -> C34 第3個工作公司代號(序號)
# c3403jid        -> C34 第3個工作職務(序號)
# c3403           -> C34 請問您的第3個工作或職務符合哪一個?
# kc3403          -> C34 請問您的第3個工作或職務符合哪一個?(15)其他,請說明
# c3503a3         -> C35 請問您的第3個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3503b5         -> C35 請問您的第3個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3603           -> C36 請問您的第3個工作這個公司或機構全體員工約有多少人?
# c3703           -> C37 請問您的第3個工作當時的職務上有沒有管人?
# c3803           -> C38 請問您的第3個工作是怎麼找到這個工作或職務?
# kc3803          -> C38 請問您的第3個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3903a          -> C39 請問您的第3個工作或職務每個星期大約工作___天?
# c3903b          -> C39 請問您的第3個工作或職務每天___小時?
# c3903c          -> C39 請問您的第3個工作或職務每個星期大約工作___小時?
# c4003           -> C40 請問您的第3個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4003a          -> C40 請問您的第3個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4103           -> C41 假如第3個不是您現在的工作或職務,請問您為什麼不做了?
# kc4103          -> C41 假如第3個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4203st         -> C42 請問您的第3個工作是民國幾年幾月開?(單位)民國年/歲數
# c4203sy         -> C42 請問您的第3個工作是民國幾年幾月開始?民國年(歲)
# c4203sm         -> C42 請問您的第3個工作是民國幾年幾月開始?月份
# c4203et         -> C42 請問您的第3個工作是民國幾年幾月結?(單位)民國年/歲數
# c4203ey         -> C42 請問您的第3個工作是民國幾年幾月結束?民國年
# c4203em         -> C42 請問您的第3個工作是民國幾年幾月結束?月份
# c4303           -> C43 請問您結束第3個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3404cid        -> C34 第4個工作公司代號(序號)
# c3404jid        -> C34 第4個工作職務(序號)
# c3404           -> C34 請問您的第4個工作或職務符合哪一個?
# kc3404          -> C34 請問您的第4個工作或職務符合哪一個?(15)其他,請說明
# c3504a3         -> C35 請問您的第4個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3504b5         -> C35 請問您的第4個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3604           -> C36 請問您的第4個工作這個公司或機構全體員工約有多少人?
# c3704           -> C37 請問您的第4個工作當時的職務上有沒有管人?
# c3804           -> C38 請問您的第4個工作是怎麼找到這個工作或職務?
# kc3804          -> C38 請問您的第4個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3904a          -> C39 請問您的第4個工作或職務每個星期大約工作___天?
# c3904b          -> C39 請問您的第4個工作或職務每天___小時?
# c3904c          -> C39 請問您的第4個工作或職務每個星期大約工作___小時?
# c4004           -> C40 請問您的第4個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4004a          -> C40 請問您的第4個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4104           -> C41 假如第4個不是您現在的工作或職務,請問您為什麼不做了?
# kc4104          -> C41 假如第4個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4204st         -> C42 請問您的第4個工作是民國幾年幾月開?(單位)民國年/歲數
# c4204sy         -> C42 請問您的第4個工作是民國幾年幾月開始?民國年(歲)
# c4204sm         -> C42 請問您的第4個工作是民國幾年幾月開始?月份
# c4204et         -> C42 請問您的第4個工作是民國幾年幾月結?(單位)民國年/歲數
# c4204ey         -> C42 請問您的第4個工作是民國幾年幾月結束?民國年
# c4204em         -> C42 請問您的第4個工作是民國幾年幾月結束?月份
# c4304           -> C43 請問您結束第4個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3405cid        -> C34 第5個工作公司代號(序號)
# c3405jid        -> C34 第5個工作職務(序號)
# c3405           -> C34 請問您的第5個工作或職務符合哪一個?
# kc3405          -> C34 請問您的第5個工作或職務符合哪一個?(15)其他,請說明
# c3505a3         -> C35 請問您的第5個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3505b5         -> C35 請問您的第5個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3605           -> C36 請問您的第5個工作這個公司或機構全體員工約有多少人?
# c3705           -> C37 請問您的第5個工作當時的職務上有沒有管人?
# c3805           -> C38 請問您的第5個工作是怎麼找到這個工作或職務?
# kc3805          -> C38 請問您的第5個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3905a          -> C39 請問您的第5個工作或職務每個星期大約工作___天?
# c3905b          -> C39 請問您的第5個工作或職務每天___小時?
# c3905c          -> C39 請問您的第5個工作或職務每個星期大約工作___小時?
# c4005           -> C40 請問您的第5個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4005a          -> C40 請問您的第5個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4105           -> C41 假如第5個不是您現在的工作或職務,請問您為什麼不做了?
# kc4105          -> C41 假如第5個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4205st         -> C42 請問您的第5個工作是民國幾年幾月開?(單位)民國年/歲數
# c4205sy         -> C42 請問您的第5個工作是民國幾年幾月開始?民國年(歲)
# c4205sm         -> C42 請問您的第5個工作是民國幾年幾月開始?月份
# c4205et         -> C42 請問您的第5個工作是民國幾年幾月結?(單位)民國年/歲數
# c4205ey         -> C42 請問您的第5個工作是民國幾年幾月結束?民國年
# c4205em         -> C42 請問您的第5個工作是民國幾年幾月結束?月份
# c4305           -> C43 請問您結束第5個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3406cid        -> C34 第6個工作公司代號(序號)
# c3406jid        -> C34 第6個工作職務(序號)
# c3406           -> C34 請問您的第6個工作或職務符合哪一個?
# kc3406          -> C34 請問您的第6個工作或職務符合哪一個?(15)其他,請說明
# c3506a3         -> C35 請問您的第6個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3506b5         -> C35 請問您的第6個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3606           -> C36 請問您的第6個工作這個公司或機構全體員工約有多少人?
# c3706           -> C37 請問您的第6個工作當時的職務上有沒有管人?
# c3806           -> C38 請問您的第6個工作是怎麼找到這個工作或職務?
# kc3806          -> C38 請問您的第6個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3906a          -> C39 請問您的第6個工作或職務每個星期大約工作___天?
# c3906b          -> C39 請問您的第6個工作或職務每天___小時?
# c3906c          -> C39 請問您的第6個工作或職務每個星期大約工作___小時?
# c4006           -> C40 請問您的第6個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4006a          -> C40 請問您的第6個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4106           -> C41 假如第6個不是您現在的工作或職務,請問您為什麼不做了?
# kc4106          -> C41 假如第6個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4206st         -> C42 請問您的第6個工作是民國幾年幾月開?(單位)民國年/歲數
# c4206sy         -> C42 請問您的第6個工作是民國幾年幾月開始?民國年(歲)
# c4206sm         -> C42 請問您的第6個工作是民國幾年幾月開始?月份
# c4206et         -> C42 請問您的第6個工作是民國幾年幾月結?(單位)民國年/歲數
# c4206ey         -> C42 請問您的第6個工作是民國幾年幾月結束?民國年
# c4206em         -> C42 請問您的第6個工作是民國幾年幾月結束?月份
# c4306           -> C43 請問您結束第6個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3407cid        -> C34 第7個工作公司代號(序號)
# c3407jid        -> C34 第7個工作職務(序號)
# c3407           -> C34 請問您的第7個工作或職務符合哪一個?
# kc3407          -> C34 請問您的第7個工作或職務符合哪一個?(15)其他,請說明
# c3507a3         -> C35 請問您的第7個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3507b5         -> C35 請問您的第7個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3607           -> C36 請問您的第7個工作這個公司或機構全體員工約有多少人?
# c3707           -> C37 請問您的第7個工作當時的職務上有沒有管人?
# c3807           -> C38 請問您的第7個工作是怎麼找到這個工作或職務?
# kc3807          -> C38 請問您的第7個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3907a          -> C39 請問您的第7個工作或職務每個星期大約工作___天?
# c3907b          -> C39 請問您的第7個工作或職務每天___小時?
# c3907c          -> C39 請問您的第7個工作或職務每個星期大約工作___小時?
# c4007           -> C40 請問您的第7個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4007a          -> C40 請問您的第7個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4107           -> C41 假如第7個不是您現在的工作或職務,請問您為什麼不做了?
# kc4107          -> C41 假如第7個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4207st         -> C42 請問您的第7個工作是民國幾年幾月開?(單位)民國年/歲數
# c4207sy         -> C42 請問您的第7個工作是民國幾年幾月開始?民國年(歲)
# c4207sm         -> C42 請問您的第7個工作是民國幾年幾月開始?月份
# c4207et         -> C42 請問您的第7個工作是民國幾年幾月結?(單位)民國年/歲數
# c4207ey         -> C42 請問您的第7個工作是民國幾年幾月結束?民國年
# c4207em         -> C42 請問您的第7個工作是民國幾年幾月結束?月份
# c4307           -> C43 請問您結束第7個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3408cid        -> C34 第8個工作公司代號(序號)
# c3408jid        -> C34 第8個工作職務(序號)
# c3408           -> C34 請問您的第8個工作或職務符合哪一個?
# kc3408          -> C34 請問您的第8個工作或職務符合哪一個?(15)其他,請說明
# c3508a3         -> C35 請問您的第8個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3508b5         -> C35 請問您的第8個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3608           -> C36 請問您的第8個工作這個公司或機構全體員工約有多少人?
# c3708           -> C37 請問您的第8個工作當時的職務上有沒有管人?
# c3808           -> C38 請問您的第8個工作是怎麼找到這個工作或職務?
# kc3808          -> C38 請問您的第8個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3908a          -> C39 請問您的第8個工作或職務每個星期大約工作___天?
# c3908b          -> C39 請問您的第8個工作或職務每天___小時?
# c3908c          -> C39 請問您的第8個工作或職務每個星期大約工作___小時?
# c4008           -> C40 請問您的第8個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4008a          -> C40 請問您的第8個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4108           -> C41 假如第8個不是您現在的工作或職務,請問您為什麼不做了?
# kc4108          -> C41 假如第8個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4208st         -> C42 請問您的第8個工作是民國幾年幾月開?(單位)民國年/歲數
# c4208sy         -> C42 請問您的第8個工作是民國幾年幾月開始?民國年(歲)
# c4208sm         -> C42 請問您的第8個工作是民國幾年幾月開始?月份
# c4208et         -> C42 請問您的第8個工作是民國幾年幾月結?(單位)民國年/歲數
# c4208ey         -> C42 請問您的第8個工作是民國幾年幾月結束?民國年
# c4208em         -> C42 請問您的第8個工作是民國幾年幾月結束?月份
# c4308           -> C43 請問您結束第8個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3409cid        -> C34 第9個工作公司代號(序號)
# c3409jid        -> C34 第9個工作職務(序號)
# c3409           -> C34 請問您的第9個工作或職務符合哪一個?
# kc3409          -> C34 請問您的第9個工作或職務符合哪一個?(15)其他,請說明
# c3509a3         -> C35 請問您的第9個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3509b5         -> C35 請問您的第9個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3609           -> C36 請問您的第9個工作這個公司或機構全體員工約有多少人?
# c3709           -> C37 請問您的第9個工作當時的職務上有沒有管人?
# c3809           -> C38 請問您的第9個工作是怎麼找到這個工作或職務?
# kc3809          -> C38 請問您的第9個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3909a          -> C39 請問您的第9個工作或職務每個星期大約工作___天?
# c3909b          -> C39 請問您的第9個工作或職務每天___小時?
# c3909c          -> C39 請問您的第9個工作或職務每個星期大約工作___小時?
# c4009           -> C40 請問您的第9個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4009a          -> C40 請問您的第9個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4109           -> C41 假如第9個不是您現在的工作或職務,請問您為什麼不做了?
# kc4109          -> C41 假如第9個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4209st         -> C42 請問您的第9個工作是民國幾年幾月開?(單位)民國年/歲數
# c4209sy         -> C42 請問您的第9個工作是民國幾年幾月開始?民國年(歲)
# c4209sm         -> C42 請問您的第9個工作是民國幾年幾月開始?月份
# c4209et         -> C42 請問您的第9個工作是民國幾年幾月結?(單位)民國年/歲數
# c4209ey         -> C42 請問您的第9個工作是民國幾年幾月結束?民國年
# c4209em         -> C42 請問您的第9個工作是民國幾年幾月結束?月份
# c4309           -> C43 請問您結束第9個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3410cid        -> C34 第10個工作公司代號(序號)
# c3410jid        -> C34 第10個工作職務(序號)
# c3410           -> C34 請問您的第10個工作或職務符合哪一個?
# kc3410          -> C34 請問您的第10個工作或職務符合哪一個?(15)其他,請說明
# c3510a3         -> C35 請問您的第10個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3510b5         -> C35 請問您的第10個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3610           -> C36 請問您的第10個工作這個公司或機構全體員工約有多少人?
# c3710           -> C37 請問您的第10個工作當時的職務上有沒有管人?
# c3810           -> C38 請問您的第10個工作是怎麼找到這個工作或職務?
# kc3810          -> C38 請問您的第10個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3910a          -> C39 請問您的第10個工作或職務每個星期大約工作___天?
# c3910b          -> C39 請問您的第10個工作或職務每天___小時?
# c3910c          -> C39 請問您的第10個工作或職務每個星期大約工作___小時?
# c4010           -> C40 請問您的第10個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4010a          -> C40 請問您的第10個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4110           -> C41 假如第10個不是您現在的工作或職務,請問您為什麼不做了?
# kc4110          -> C41 假如第10個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4210st         -> C42 請問您的第10個工作是民國幾年幾月開?(單位)民國年/歲數
# c4210sy         -> C42 請問您的第10個工作是民國幾年幾月開始?民國年(歲)
# c4210sm         -> C42 請問您的第10個工作是民國幾年幾月開始?月份
# c4210et         -> C42 請問您的第10個工作是民國幾年幾月結?(單位)民國年/歲數
# c4210ey         -> C42 請問您的第10個工作是民國幾年幾月結束?民國年
# c4210em         -> C42 請問您的第10個工作是民國幾年幾月結束?月份
# c4310           -> C43 請問您結束第10個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3411cid        -> C34 第11個工作公司代號(序號)
# c3411jid        -> C34 第11個工作職務(序號)
# c3411           -> C34 請問您的第11個工作或職務符合哪一個?
# kc3411          -> C34 請問您的第11個工作或職務符合哪一個?(15)其他,請說明
# c3511a3         -> C35 請問您的第11個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3511b5         -> C35 請問您的第11個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3611           -> C36 請問您的第11個工作這個公司或機構全體員工約有多少人?
# c3711           -> C37 請問您的第11個工作當時的職務上有沒有管人?
# c3811           -> C38 請問您的第11個工作是怎麼找到這個工作或職務?
# kc3811          -> C38 請問您的第11個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3911a          -> C39 請問您的第11個工作或職務每個星期大約工作___天?
# c3911b          -> C39 請問您的第11個工作或職務每天___小時?
# c3911c          -> C39 請問您的第11個工作或職務每個星期大約工作___小時?
# c4011           -> C40 請問您的第11個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4011a          -> C40 請問您的第11個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4111           -> C41 假如第11個不是您現在的工作或職務,請問您為什麼不做了?
# kc4111          -> C41 假如第11個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4211sy         -> C42 請問您的第11個工作是民國幾年幾月開始?民國年
# c4211sm         -> C42 請問您的第11個工作是民國幾年幾月開始?月份
# c4211ey         -> C42 請問您的第11個工作是民國幾年幾月結束?民國年
# c4211em         -> C42 請問您的第11個工作是民國幾年幾月結束?月份
# c4311           -> C43 請問您結束第11個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3412cid        -> C34 第12個工作公司代號(序號)
# c3412jid        -> C34 第12個工作職務(序號)
# c3412           -> C34 請問您的第12個工作或職務符合哪一個?
# kc3412          -> C34 請問您的第12個工作或職務符合哪一個?(15)其他,請說明
# c3512a3         -> C35 請問您的第12個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3512b5         -> C35 請問您的第12個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3612           -> C36 請問您的第12個工作這個公司或機構全體員工約有多少人?
# c3712           -> C37 請問您的第12個工作當時的職務上有沒有管人?
# c3812           -> C38 請問您的第12個工作是怎麼找到這個工作或職務?
# kc3812          -> C38 請問您的第12個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3912a          -> C39 請問您的第12個工作或職務每個星期大約工作___天?
# c3912b          -> C39 請問您的第12個工作或職務每天___小時?
# c3912c          -> C39 請問您的第12個工作或職務每個星期大約工作___小時?
# c4012           -> C40 請問您的第12個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4012a          -> C40 請問您的第12個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4112           -> C41 假如第12個不是您現在的工作或職務,請問您為什麼不做了?
# kc4112          -> C41 假如第12個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4212sy         -> C42 請問您的第12個工作是民國幾年幾月開始?民國年
# c4212sm         -> C42 請問您的第12個工作是民國幾年幾月開始?月份
# c4212ey         -> C42 請問您的第12個工作是民國幾年幾月結束?民國年
# c4212em         -> C42 請問您的第12個工作是民國幾年幾月結束?月份
# c4312           -> C43 請問您結束第12個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3413cid        -> C34 第13個工作公司代號(序號)
# c3413jid        -> C34 第13個工作職務(序號)
# c3413           -> C34 請問您的第13個工作或職務符合哪一個?
# kc3413          -> C34 請問您的第13個工作或職務符合哪一個?(15)其他,請說明
# c3513a3         -> C35 請問您的第13個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3513b5         -> C35 請問您的第13個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3613           -> C36 請問您的第13個工作這個公司或機構全體員工約有多少人?
# c3713           -> C37 請問您的第13個工作當時的職務上有沒有管人?
# c3813           -> C38 請問您的第13個工作是怎麼找到這個工作或職務?
# kc3813          -> C38 請問您的第13個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3913a          -> C39 請問您的第13個工作或職務每個星期大約工作___天?
# c3913b          -> C39 請問您的第13個工作或職務每天___小時?
# c3913c          -> C39 請問您的第13個工作或職務每個星期大約工作___小時?
# c4013           -> C40 請問您的第13個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4013a          -> C40 請問您的第13個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4113           -> C41 假如第13個不是您現在的工作或職務,請問您為什麼不做了?
# kc4113          -> C41 假如第13個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4213sy         -> C42 請問您的第13個工作是民國幾年幾月開始?民國年
# c4213sm         -> C42 請問您的第13個工作是民國幾年幾月開始?月份
# c4213ey         -> C42 請問您的第13個工作是民國幾年幾月結束?民國年
# c4213em         -> C42 請問您的第13個工作是民國幾年幾月結束?月份
# c4313           -> C43 請問您結束第13個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3414cid        -> C34 第14個工作公司代號(序號)
# c3414jid        -> C34 第14個工作職務(序號)
# c3414           -> C34 請問您的第14個工作或職務符合哪一個?
# kc3414          -> C34 請問您的第14個工作或職務符合哪一個?(15)其他,請說明
# c3514a3         -> C35 請問您的第14個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3514b5         -> C35 請問您的第14個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3614           -> C36 請問您的第14個工作這個公司或機構全體員工約有多少人?
# c3714           -> C37 請問您的第14個工作當時的職務上有沒有管人?
# c3814           -> C38 請問您的第14個工作是怎麼找到這個工作或職務?
# kc3814          -> C38 請問您的第14個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3914a          -> C39 請問您的第14個工作或職務每個星期大約工作___天?
# c3914b          -> C39 請問您的第14個工作或職務每天___小時?
# c3914c          -> C39 請問您的第14個工作或職務每個星期大約工作___小時?
# c4014           -> C40 請問您的第14個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4014a          -> C40 請問您的第14個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4114           -> C41 假如第14個不是您現在的工作或職務,請問您為什麼不做了?
# kc4114          -> C41 假如第14個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4214sy         -> C42 請問您的第14個工作是民國幾年幾月開始?民國年
# c4214sm         -> C42 請問您的第14個工作是民國幾年幾月開始?月份
# c4214ey         -> C42 請問您的第14個工作是民國幾年幾月結束?民國年
# c4214em         -> C42 請問您的第14個工作是民國幾年幾月結束?月份
# c4314           -> C43 請問您結束第14個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3415cid        -> C34 第15個工作公司代號(序號)
# c3415jid        -> C34 第15個工作職務(序號)
# c3415           -> C34 請問您的第15個工作或職務符合哪一個?
# kc3415          -> C34 請問您的第15個工作或職務符合哪一個?(15)其他,請說明
# c3515a3         -> C35 請問您的第15個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3515b5         -> C35 請問您的第15個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3615           -> C36 請問您的第15個工作這個公司或機構全體員工約有多少人?
# c3715           -> C37 請問您的第15個工作當時的職務上有沒有管人?
# c3815           -> C38 請問您的第15個工作是怎麼找到這個工作或職務?
# kc3815          -> C38 請問您的第15個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3915a          -> C39 請問您的第15個工作或職務每個星期大約工作___天?
# c3915b          -> C39 請問您的第15個工作或職務每天___小時?
# c3915c          -> C39 請問您的第15個工作或職務每個星期大約工作___小時?
# c4015           -> C40 請問您的第15個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4015a          -> C40 請問您的第15個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4115           -> C41 假如第15個不是您現在的工作或職務,請問您為什麼不做了?
# kc4115          -> C41 假如第15個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4215sy         -> C42 請問您的第15個工作是民國幾年幾月開始?民國年
# c4215sm         -> C42 請問您的第15個工作是民國幾年幾月開始?月份
# c4215ey         -> C42 請問您的第15個工作是民國幾年幾月結束?民國年
# c4215em         -> C42 請問您的第15個工作是民國幾年幾月結束?月份
# c4315           -> C43 請問您結束第15個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3416cid        -> C34 第16個工作公司代號(序號)
# c3416jid        -> C34 第16個工作職務(序號)
# c3416           -> C34 請問您的第16個工作或職務符合哪一個?
# kc3416          -> C34 請問您的第16個工作或職務符合哪一個?(15)其他,請說明
# c3516a3         -> C35 請問您的第16個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3516b5         -> C35 請問您的第16個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3616           -> C36 請問您的第16個工作這個公司或機構全體員工約有多少人?
# c3716           -> C37 請問您的第16個工作當時的職務上有沒有管人?
# c3816           -> C38 請問您的第16個工作是怎麼找到這個工作或職務?
# kc3816          -> C38 請問您的第16個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3916a          -> C39 請問您的第16個工作或職務每個星期大約工作___天?
# c3916b          -> C39 請問您的第16個工作或職務每天___小時?
# c3916c          -> C39 請問您的第16個工作或職務每個星期大約工作___小時?
# c4016           -> C40 請問您的第16個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4016a          -> C40 請問您的第16個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4116           -> C41 假如第16個不是您現在的工作或職務,請問您為什麼不做了?
# kc4116          -> C41 假如第16個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4216sy         -> C42 請問您的第16個工作是民國幾年幾月開始?民國年
# c4216sm         -> C42 請問您的第16個工作是民國幾年幾月開始?月份
# c4216ey         -> C42 請問您的第16個工作是民國幾年幾月結束?民國年
# c4216em         -> C42 請問您的第16個工作是民國幾年幾月結束?月份
# c4316           -> C43 請問您結束第16個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3417cid        -> C34 第17個工作公司代號(序號)
# c3417jid        -> C34 第17個工作職務(序號)
# c3417           -> C34 請問您的第17個工作或職務符合哪一個?
# kc3417          -> C34 請問您的第17個工作或職務符合哪一個?(15)其他,請說明
# c3517a3         -> C35 請問您的第17個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3517b5         -> C35 請問您的第17個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3617           -> C36 請問您的第17個工作這個公司或機構全體員工約有多少人?
# c3717           -> C37 請問您的第17個工作當時的職務上有沒有管人?
# c3817           -> C38 請問您的第17個工作是怎麼找到這個工作或職務?
# kc3817          -> C38 請問您的第17個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3917a          -> C39 請問您的第17個工作或職務每個星期大約工作___天?
# c3917b          -> C39 請問您的第17個工作或職務每天___小時?
# c3917c          -> C39 請問您的第17個工作或職務每個星期大約工作___小時?
# c4017           -> C40 請問您的第17個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4017a          -> C40 請問您的第17個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4117           -> C41 假如第17個不是您現在的工作或職務,請問您為什麼不做了?
# kc4117          -> C41 假如第17個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4217sy         -> C42 請問您的第17個工作是民國幾年幾月開始?民國年
# c4217sm         -> C42 請問您的第17個工作是民國幾年幾月開始?月份
# c4217ey         -> C42 請問您的第17個工作是民國幾年幾月結束?民國年
# c4217em         -> C42 請問您的第17個工作是民國幾年幾月結束?月份
# c4317           -> C43 請問您結束第17個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3418cid        -> C34 第18個工作公司代號(序號)
# c3418jid        -> C34 第18個工作職務(序號)
# c3418           -> C34 請問您的第18個工作或職務符合哪一個?
# kc3418          -> C34 請問您的第18個工作或職務符合哪一個?(15)其他,請說明
# c3518a3         -> C35 請問您的第18個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3518b5         -> C35 請問您的第18個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3618           -> C36 請問您的第18個工作這個公司或機構全體員工約有多少人?
# c3718           -> C37 請問您的第18個工作當時的職務上有沒有管人?
# c3818           -> C38 請問您的第18個工作是怎麼找到這個工作或職務?
# kc3818          -> C38 請問您的第18個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3918a          -> C39 請問您的第18個工作或職務每個星期大約工作___天?
# c3918b          -> C39 請問您的第18個工作或職務每天___小時?
# c3918c          -> C39 請問您的第18個工作或職務每個星期大約工作___小時?
# c4018           -> C40 請問您的第18個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4018a          -> C40 請問您的第18個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4118           -> C41 假如第18個不是您現在的工作或職務,請問您為什麼不做了?
# kc4118          -> C41 假如第18個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4218sy         -> C42 請問您的第18個工作是民國幾年幾月開始?民國年
# c4218sm         -> C42 請問您的第18個工作是民國幾年幾月開始?月份
# c4218ey         -> C42 請問您的第18個工作是民國幾年幾月結束?民國年
# c4218em         -> C42 請問您的第18個工作是民國幾年幾月結束?月份
# c4318           -> C43 請問您結束第18個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3419cid        -> C34 第19個工作公司代號(序號)
# c3419jid        -> C34 第19個工作職務(序號)
# c3419           -> C34 請問您的第19個工作或職務符合哪一個?
# kc3419          -> C34 請問您的第19個工作或職務符合哪一個?(15)其他,請說明
# c3519a3         -> C35 請問您的第19個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3519b5         -> C35 請問您的第19個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3619           -> C36 請問您的第19個工作這個公司或機構全體員工約有多少人?
# c3719           -> C37 請問您的第19個工作當時的職務上有沒有管人?
# c3819           -> C38 請問您的第19個工作是怎麼找到這個工作或職務?
# kc3819          -> C38 請問您的第19個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3919a          -> C39 請問您的第19個工作或職務每個星期大約工作___天?
# c3919b          -> C39 請問您的第19個工作或職務每天___小時?
# c3919c          -> C39 請問您的第19個工作或職務每個星期大約工作___小時?
# c4019           -> C40 請問您的第19個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4019a          -> C40 請問您的第19個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4119           -> C41 假如第19個不是您現在的工作或職務,請問您為什麼不做了?
# kc4119          -> C41 假如第19個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4219sy         -> C42 請問您的第19個工作是民國幾年幾月開始?民國年
# c4219sm         -> C42 請問您的第19個工作是民國幾年幾月開始?月份
# c4219ey         -> C42 請問您的第19個工作是民國幾年幾月結束?民國年
# c4219em         -> C42 請問您的第19個工作是民國幾年幾月結束?月份
# c4319           -> C43 請問您結束第19個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3420cid        -> C34 第20個工作公司代號(序號)
# c3420jid        -> C34 第20個工作職務(序號)
# c3420           -> C34 請問您的第20個工作或職務符合哪一個?
# kc3420          -> C34 請問您的第20個工作或職務符合哪一個?(15)其他,請說明
# c3520a3         -> C35 請問您的第20個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3520b5         -> C35 請問您的第20個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3620           -> C36 請問您的第20個工作這個公司或機構全體員工約有多少人?
# c3720           -> C37 請問您的第20個工作當時的職務上有沒有管人?
# c3820           -> C38 請問您的第20個工作是怎麼找到這個工作或職務?
# kc3820          -> C38 請問您的第20個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3920a          -> C39 請問您的第20個工作或職務每個星期大約工作___天?
# c3920b          -> C39 請問您的第20個工作或職務每天___小時?
# c3920c          -> C39 請問您的第20個工作或職務每個星期大約工作___小時?
# c4020           -> C40 請問您的第20個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4020a          -> C40 請問您的第20個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4120           -> C41 假如第20個不是您現在的工作或職務,請問您為什麼不做了?
# kc4120          -> C41 假如第20個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4220sy         -> C42 請問您的第20個工作是民國幾年幾月開始?民國年
# c4220sm         -> C42 請問您的第20個工作是民國幾年幾月開始?月份
# c4220ey         -> C42 請問您的第20個工作是民國幾年幾月結束?民國年
# c4220em         -> C42 請問您的第20個工作是民國幾年幾月結束?月份
# c4320           -> C43 請問您結束第20個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3421cid        -> C34 第21個工作公司代號(序號)
# c3421jid        -> C34 第21個工作職務(序號)
# c3421           -> C34 請問您的第21個工作或職務符合哪一個?
# kc3421          -> C34 請問您的第21個工作或職務符合哪一個?(15)其他,請說明
# c3521a3         -> C35 請問您的第21個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3521b5         -> C35 請問您的第21個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3621           -> C36 請問您的第21個工作這個公司或機構全體員工約有多少人?
# c3721           -> C37 請問您的第21個工作當時的職務上有沒有管人?
# c3821           -> C38 請問您的第21個工作是怎麼找到這個工作或職務?
# kc3821          -> C38 請問您的第21個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3921a          -> C39 請問您的第21個工作或職務每個星期大約工作___天?
# c3921b          -> C39 請問您的第21個工作或職務每天___小時?
# c3921c          -> C39 請問您的第21個工作或職務每個星期大約工作___小時?
# c4021           -> C40 請問您的第21個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4021a          -> C40 請問您的第21個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4121           -> C41 假如第21個不是您現在的工作或職務,請問您為什麼不做了?
# kc4121          -> C41 假如第21個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4221sy         -> C42 請問您的第21個工作是民國幾年幾月開始?民國年
# c4221sm         -> C42 請問您的第21個工作是民國幾年幾月開始?月份
# c4221ey         -> C42 請問您的第21個工作是民國幾年幾月結束?民國年
# c4221em         -> C42 請問您的第21個工作是民國幾年幾月結束?月份
# c4321           -> C43 請問您結束第21個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3422cid        -> C34 第22個工作公司代號(序號)
# c3422jid        -> C34 第22個工作職務(序號)
# c3422           -> C34 請問您的第22個工作或職務符合哪一個?
# kc3422          -> C34 請問您的第22個工作或職務符合哪一個?(15)其他,請說明
# c3522a3         -> C35 請問您的第22個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3522b5         -> C35 請問您的第22個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3622           -> C36 請問您的第22個工作這個公司或機構全體員工約有多少人?
# c3722           -> C37 請問您的第22個工作當時的職務上有沒有管人?
# c3822           -> C38 請問您的第22個工作是怎麼找到這個工作或職務?
# kc3822          -> C38 請問您的第22個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3922a          -> C39 請問您的第22個工作或職務每個星期大約工作___天?
# c3922b          -> C39 請問您的第22個工作或職務每天___小時?
# c3922c          -> C39 請問您的第22個工作或職務每個星期大約工作___小時?
# c4022           -> C40 請問您的第22個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4022a          -> C40 請問您的第22個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4122           -> C41 假如第22個不是您現在的工作或職務,請問您為什麼不做了?
# kc4122          -> C41 假如第22個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4222sy         -> C42 請問您的第22個工作是民國幾年幾月開始?民國年
# c4222sm         -> C42 請問您的第22個工作是民國幾年幾月開始?月份
# c4222ey         -> C42 請問您的第22個工作是民國幾年幾月結束?民國年
# c4222em         -> C42 請問您的第22個工作是民國幾年幾月結束?月份
# c4322           -> C43 請問您結束第22個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# c3423cid        -> C34 第23個工作公司代號(序號)
# c3423jid        -> C34 第23個工作職務(序號)
# c3423           -> C34 請問您的第23個工作或職務符合哪一個?
# kc3423          -> C34 請問您的第23個工作或職務符合哪一個?(15)其他,請說明
# c3523a3         -> C35 請問您的第23個工作這家公司/機構的名稱和職務為何?(a3)行業碼
# c3523b5         -> C35 請問您的第23個工作這家公司/機構的名稱和職務為何?(b5)ISCO08職業碼
# c3623           -> C36 請問您的第23個工作這個公司或機構全體員工約有多少人?
# c3723           -> C37 請問您的第23個工作當時的職務上有沒有管人?
# c3823           -> C38 請問您的第23個工作是怎麼找到這個工作或職務?
# kc3823          -> C38 請問您的第23個工作是怎麼找到這個工作或職務?(14)其他,請說明
# c3923a          -> C39 請問您的第23個工作或職務每個星期大約工作___天?
# c3923b          -> C39 請問您的第23個工作或職務每天___小時?
# c3923c          -> C39 請問您的第23個工作或職務每個星期大約工作___小時?
# c4023           -> C40 請問您的第23個工作結束平均每月所有的工作收入差不多有多少?(級距)
# c4023a          -> C40 請問您的第23個工作結束平均每月所有的工作收入差不多有多少?(數值)
# c4123           -> C41 假如第23個不是您現在的工作或職務,請問您為什麼不做了?
# kc4123          -> C41 假如第23個不是您現在的工作或職務,請問您為什麼不做了?(14)其他,請說明
# c4223sy         -> C42 請問您的第23個工作是民國幾年幾月開始?民國年
# c4223sm         -> C42 請問您的第23個工作是民國幾年幾月開始?月份
# c4223ey         -> C42 請問您的第23個工作是民國幾年幾月結束?民國年
# c4223em         -> C42 請問您的第23個工作是民國幾年幾月結束?月份
# c4323           -> C43 請問您結束第23個工作到下一個工作或職務期間有沒有超過三個月以上沒有工作
# d101            -> D1 請問您目前參加了哪些社會團體?(01)宗親會
# d102            -> D1 請問您目前參加了哪些社會團體?(02)職業團體
# d103            -> D1 請問您目前參加了哪些社會團體?(03)宗教團體
# d104            -> D1 請問您目前參加了哪些社會團體?(04)同鄉會
# d105            -> D1 請問您目前參加了哪些社會團體?(05)康樂團體
# d106            -> D1 請問您目前參加了哪些社會團體?(06)校友會
# d107            -> D1 請問您目前參加了哪些社會團體?(07)祠堂,祭祀公業
# d108            -> D1 請問您目前參加了哪些社會團體?(08)社會團體
# d109            -> D1 請問您目前參加了哪些社會團體?(09)社區管理委員會,社區發展協會或自治會
# d110            -> D1 請問您目前參加了哪些社會團體?(10)其他團體
# d111            -> D1 請問您目前參加了哪些社會團體?(11)都沒有
# kd110           -> D1 請問您目前參加了哪些社會團體?(10)其他團體(請說明)
# d2              -> D2 請問您平常一天裡面,從早到晚大概總共跟多少人接觸?
# d3a             -> D3 請問在您所有認識的人裡面,有沒有在做:a大學教授
# d3b             -> D3 請問在您所有認識的人裡面,有沒有在做:b律師
# d3c             -> D3 請問在您所有認識的人裡面,有沒有在做:c護士
# d3d             -> D3 請問在您所有認識的人裡面,有沒有在做:d電腦程式設計師
# d3e             -> D3 請問在您所有認識的人裡面,有沒有在做:e中學老師
# d3f             -> D3 請問在您所有認識的人裡面,有沒有在做:f人事主管
# d3g             -> D3 請問在您所有認識的人裡面,有沒有在做:g農民
# d3h             -> D3 請問在您所有認識的人裡面,有沒有在做:h美髮師
# d3i             -> D3 請問在您所有認識的人裡面,有沒有在做:i櫃臺接待
# d3j             -> D3 請問在您所有認識的人裡面,有沒有在做:j警察
# d4              -> D4 一般說來,請問您認為大部分的人是可以信任的嗎?
# e1              -> E1 社會中分層10層,有些人接近上層(10),有些人接近下層(1),您認為自己是哪一層?
# e2              -> E2 把社會上所有的人分成上層,中上層,中層,中下層,勞工階級和下層階級請問您認為自己屬於那個階級?
# e3              -> E3 去年一月的總統選舉,請問您有沒有去投票?投給誰?
# e4              -> E4 國內的政黨都有他們的支持者,請問您是哪一個黨的支持者?
# ke4             -> E4 國內的政黨都有他們的支持者,請問您是哪一個黨的支持者?(08)其他政黨(請說明)
# e5              -> E5 一般而言,請問您會比較偏向哪一個政黨?
# ke5             -> E5 一般而言,請問您會比較偏向哪一個政黨?(08)其他政黨(請說明)
# f1              -> F1 請問您家中,包含您本人在內,現在有幾個人住在一起?
# f201            -> F2 請問您家裡現在有哪些人住在一起?(01)曾祖父/母
# f202            -> F2 請問您家裡現在有哪些人住在一起?(02)祖父/母
# f203            -> F2 請問您家裡現在有哪些人住在一起?(03)外祖父/母
# f204            -> F2 請問您家裡現在有哪些人住在一起?(04)父
# f205            -> F2 請問您家裡現在有哪些人住在一起?(05)母
# f206            -> F2 請問您家裡現在有哪些人住在一起?(06)公公
# f207            -> F2 請問您家裡現在有哪些人住在一起?(07)婆婆
# f208            -> F2 請問您家裡現在有哪些人住在一起?(08)岳父
# f209            -> F2 請問您家裡現在有哪些人住在一起?(09)岳母
# f210            -> F2 請問您家裡現在有哪些人住在一起?(10)配偶/同居伴侶
# f211            -> F2 請問您家裡現在有哪些人住在一起?(11)未婚的兄弟姊妹
# f212            -> F2 請問您家裡現在有哪些人住在一起?(12)已婚的兄弟姊妹
# f213            -> F2 請問您家裡現在有哪些人住在一起?(13)已婚兄弟姊妹的配偶
# f214            -> F2 請問您家裡現在有哪些人住在一起?(14)子
# f215            -> F2 請問您家裡現在有哪些人住在一起?(15)媳婦
# f216            -> F2 請問您家裡現在有哪些人住在一起?(16)女
# f217            -> F2 請問您家裡現在有哪些人住在一起?(17)女婿
# f218            -> F2 請問您家裡現在有哪些人住在一起?(18)孫子/孫女
# f219            -> F2 請問您家裡現在有哪些人住在一起?(19)外孫/外孫女
# f220            -> F2 請問您家裡現在有哪些人住在一起?(20)姪/甥
# f221            -> F2 請問您家裡現在有哪些人住在一起?(21)伯叔/伯叔母
# f222            -> F2 請問您家裡現在有哪些人住在一起?(22)舅父/舅母
# f223            -> F2 請問您家裡現在有哪些人住在一起?(23)姑父/姑母
# f224            -> F2 請問您家裡現在有哪些人住在一起?(24)姨丈/姨母
# f225            -> F2 請問您家裡現在有哪些人住在一起?(25)其他,請說明
# kf225           -> F2 請問您家裡現在有哪些人住在一起?(25)其他,請說明
# f3              -> F3 請問這一年來,您的健康狀況好不好?
# f4              -> F4 整體來說,請問您覺得目前的日子過得快樂嗎?
# f5a             -> F5 請問在上星期裡,您會不會有以下這些感覺?(a)原來不煩惱的事,開始令我煩惱
# f5b             -> F5 請問在上星期裡,您會不會有以下這些感覺?(b)覺得做什麼事都很吃力
# f5c             -> F5 請問在上星期裡,您會不會有以下這些感覺?(c)感到害怕
# f5d             -> F5 請問在上星期裡,您會不會有以下這些感覺?(d)感到悲傷
# f6              -> F6 請問您配偶平均每月所有的工作收入差不多多少?
# f7              -> F7 包括各種收入來源,請問您全家人的所有稅前收入,每個月大約多少元?
# f8              -> F8 請問您最常使用的即時通信軟體是哪一個?
# kf8             -> F8 請問您最常使用的即時通信軟體是哪一個?(09)其他,請說明
# phone           -> PHONE 請問您使用的家用市內電話中,平常會用來接聽電話的號碼有幾個?
# cell            -> CELL 請問您平常會使用的手機門號有幾個?
# f9              -> F9 請問您平常在家使用電話的習慣,是用市內電話比較多,還是用手機比較多?
# edt1            -> edt 訪問結束日期
# edt2            -> edt 訪問結束時間【24小時制】
# a5zipn          -> A5 請問您現在居住在哪裡?(新增變項)
# b2c01sn         -> B2c01 請問國中畢業後第01個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c01en         -> B2c01 請問國中畢業後第01個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c02sn         -> B2c02 請問國中畢業後第02個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c02en         -> B2c02 請問國中畢業後第02個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c03sn         -> B2c03 請問國中畢業後第03個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c03en         -> B2c03 請問國中畢業後第03個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c04sn         -> B2c04 請問國中畢業後第04個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c04en         -> B2c04 請問國中畢業後第04個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c05sn         -> B2c05 請問國中畢業後第05個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c05en         -> B2c05 請問國中畢業後第05個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c06sn         -> B2c06 請問國中畢業後第06個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c06en         -> B2c06 請問國中畢業後第06個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b2c07sn         -> B2c07 請問國中畢業後第07個學校您民國幾年到幾年就讀這個學校?(01)開始就讀年(新增變項)
# b2c07en         -> B2c07 請問國中畢業後第07個學校您民國幾年到幾年就讀這個學校?(02)結束就讀年(新增變項)
# b5n             -> B5 有__個結婚經歷(新增變項)
# b5s01n          -> B5 第01段結婚經歷-(01)開始年(新增變項)
# b5e01n          -> B5 第01段結婚經歷-(02)結束年(新增變項)
# b5s02n          -> B5 第02段結婚經歷-(01)開始年(新增變項)
# b5e02n          -> B5 第02段結婚經歷-(02)結束年(新增變項)
# b5s03n          -> B5 第03段結婚經歷-(01)開始年(新增變項)
# b5e03n          -> B5 第03段結婚經歷-(02)結束年(新增變項)
# b6n             -> B6 有__個分居/離婚經歷(新增變項)
# b6s01n          -> B6 第01段分居/離婚經歷-(01)開始年(新增變項)
# b6e01n          -> B6 第01段分居/離婚經歷-(02)結束年(新增變項)
# b6s02n          -> B6 第02段分居/離婚經歷-(01)開始年(新增變項)
# b6e02n          -> B6 第02段分居/離婚經歷-(02)結束年(新增變項)
# b6s03n          -> B6 第03段分居/離婚經歷-(01)開始年(新增變項)
# b6e03n          -> B6 第03段分居/離婚經歷-(02)結束年(新增變項)
# c1n             -> C1 您國(初)中畢業或15歲時,請問父親還在嗎?有沒有工作?(新增變項)
# c6n             -> C6 您國(初)中畢業或15歲時,請問母親還在嗎?有沒有工作?(新增變項)
# c24n            -> C24 請問您目前這個工作或職務平均每月所有的工作收入差不多有多少?(新增變項)
# c26stn          -> C26 請問您民國幾年幾月開始目前這個工作或職務?(單位)民國年/歲數(新增變項)
# c26syn          -> C26 請問您民國幾年幾月開始目前這個工作或職務?民國年(新增變項)
# c26etn          -> C26 請問您民國幾年幾月結束目前這個工作或職務?(單位)民國年/歲數(新增變項)
# c26eyn          -> C26 請問您民國幾年幾月結束目前這個工作或職務?民國年(新增變項)
# c33n            -> C33 請問您第一份工作剛開始做的時候,每個月的收入是多少?(新增變項)
# c4001n          -> C40 請問您的第01個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4002n          -> C40 請問您的第02個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4003n          -> C40 請問您的第03個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4004n          -> C40 請問您的第04個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4005n          -> C40 請問您的第05個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4006n          -> C40 請問您的第06個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4007n          -> C40 請問您的第07個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4008n          -> C40 請問您的第08個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4009n          -> C40 請問您的第09個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4010n          -> C40 請問您的第10個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4011n          -> C40 請問您的第11個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4012n          -> C40 請問您的第12個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4013n          -> C40 請問您的第13個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4014n          -> C40 請問您的第14個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4015n          -> C40 請問您的第15個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4016n          -> C40 請問您的第16個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4017n          -> C40 請問您的第17個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4018n          -> C40 請問您的第18個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4019n          -> C40 請問您的第19個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4020n          -> C40 請問您的第20個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4021n          -> C40 請問您的第21個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4022n          -> C40 請問您的第22個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4023n          -> C40 請問您的第23個工作結束(目前)平均每月所有的工作收入差不多有多少?(新增變項)
# c4201syn        -> C42 請問您民國幾年開始第01個工作或職務?民國__年(新增變項)
# c4201eyn        -> C42 請問您民國幾年結束第01個工作活職務?民國__年(新增變項)
# c4202syn        -> C42 請問您民國幾年開始第02個工作或職務?民國__年(新增變項)
# c4202eyn        -> C42 請問您民國幾年結束第02個工作活職務?民國__年(新增變項)
# c4203syn        -> C42 請問您民國幾年開始第03個工作或職務?民國__年(新增變項)
# c4203eyn        -> C42 請問您民國幾年結束第03個工作活職務?民國__年(新增變項)
# c4204syn        -> C42 請問您民國幾年開始第04個工作或職務?民國__年(新增變項)
# c4204eyn        -> C42 請問您民國幾年結束第04個工作活職務?民國__年(新增變項)
# c4205syn        -> C42 請問您民國幾年開始第05個工作活職務?民國__年(新增變項)
# c4205eyn        -> C42 請問您民國幾年結束第05個工作或職務?民國__年(新增變項)
# e1n             -> E1 社會中分層10層,有些人接近上層(1),有些人接近下層(10),您認為自己是哪一層?
# e3n             -> E3 去年一月的總統選舉,請問您有沒有去投票?投給誰?(新增變項)

# %%
# Invesgating Value Labels

year = 2017
target_var = "zip"

# --- 檢查變項是否存在 ---
if target_var in datasets[year].columns:
    
    # 3. 獲取選項對應 (Value Labels) - 即「答案選項是什麼」
    # meta.variable_value_labels 是一個字典 {變項名: {數值: 標籤}}
    val_labels = metadata[year].variable_value_labels.get(target_var, {})

    # --- 輸出結果 ---
    print(f"Variable: {target_var}")
    print("-" * 30)
    print("Value Labels:")
    
    if val_labels:
        for value, label in val_labels.items():
            # 數值通常是 float，這裡印出來時不一定要顯示小數點
            print(f"   {int(value)} = {label}")
    else:
        print("   (此變項沒有設定數值標籤，可能是連續變數或文字)")

    print("-" * 30)
    print(datasets[year][target_var].value_counts())

else:
    print(f"❌ 找不到變項 '{target_var}'。請檢查拼字或大小寫。")
# Out:
# Variable: zip
# ------------------------------
# Value Labels:
#    100 = 台北市中正區
#    103 = 台北市大同區
#    104 = 台北市中山區
#    105 = 台北市松山區
#    106 = 台北市大安區
#    108 = 台北市萬華區
#    110 = 台北市信義區
#    111 = 台北市士林區
#    112 = 台北市北投區
#    114 = 台北市內湖區
#    115 = 台北市南港區
#    116 = 台北市文山區
#    200 = 基隆市仁愛區
#    201 = 基隆市信義區
#    202 = 基隆市中正區
#    203 = 基隆市中山區
#    204 = 基隆市安樂區
#    205 = 基隆市暖暖區
#    206 = 基隆市七堵區
#    207 = 新北市萬里區
#    208 = 新北市金山區
#    220 = 新北市板橋區
#    221 = 新北市汐止區
#    222 = 新北市深坑區
#    223 = 新北市石碇區
#    224 = 新北市瑞芳區
#    226 = 新北市平溪區
#    227 = 新北市雙溪區
#    228 = 新北市貢寮區
#    231 = 新北市新店區
#    232 = 新北市坪林區
#    233 = 新北市烏來區
#    234 = 新北市永和區
#    235 = 新北市中和區
#    236 = 新北市土城區
#    237 = 新北市三峽區
#    238 = 新北市樹林區
#    239 = 新北市鶯歌區
#    241 = 新北市三重區
#    242 = 新北市新莊區
#    243 = 新北市泰山區
#    244 = 新北市林口區
#    247 = 新北市蘆洲區
#    248 = 新北市五股區
#    249 = 新北市八里區
#    251 = 新北市淡水區
#    252 = 新北市三芝區
#    253 = 新北市石門區
#    260 = 宜蘭縣宜蘭市
#    261 = 宜蘭縣頭城鎮
#    262 = 宜蘭縣礁溪鄉
#    263 = 宜蘭縣壯圍鄉
#    264 = 宜蘭縣員山鄉
#    265 = 宜蘭縣羅東鎮
#    266 = 宜蘭縣三星鄉
#    267 = 宜蘭縣大同鄉
#    268 = 宜蘭縣五結鄉
#    269 = 宜蘭縣冬山鄉
#    270 = 宜蘭縣蘇澳鎮
#    272 = 宜蘭縣南澳鄉
#    300 = 新竹市
#    302 = 新竹縣竹北市
#    303 = 新竹縣湖口鄉
#    304 = 新竹縣新豐鄉
#    305 = 新竹縣新埔鎮
#    306 = 新竹縣關西鎮
#    307 = 新竹縣芎林鄉
#    308 = 新竹縣寶山鄉
#    310 = 新竹縣竹東鎮
#    311 = 新竹縣五峰鄉
#    312 = 新竹縣橫山鄉
#    313 = 新竹縣尖石鄉
#    314 = 新竹縣北埔鄉
#    315 = 新竹縣峨眉鄉
#    320 = 桃園市中壢區
#    324 = 桃園市平鎮區
#    325 = 桃園市龍潭區
#    326 = 桃園市楊梅區
#    327 = 桃園市新屋區
#    328 = 桃園市觀音區
#    330 = 桃園市桃園區
#    333 = 桃園市龜山區
#    334 = 桃園市八德區
#    335 = 桃園市大溪區
#    336 = 桃園市復興區
#    337 = 桃園市大園區
#    338 = 桃園市蘆竹區
#    350 = 苖栗縣竹南鎮
#    351 = 苖栗縣頭份鎮
#    352 = 苖栗縣三灣鄉
#    353 = 苖栗縣南庄鄉
#    354 = 苖栗縣獅潭鄉
#    356 = 苖栗縣後龍鎮
#    357 = 苖栗縣通霄鎮
#    358 = 苖栗縣苑裡鎮
#    360 = 苖栗縣苖栗市
#    361 = 苖栗縣造橋鄉
#    362 = 苖栗縣頭屋鄉
#    363 = 苖栗縣公館鄉
#    364 = 苖栗縣大湖鄉
#    365 = 苖栗縣泰安鄉
#    366 = 苖栗縣銅鑼鄉
#    367 = 苖栗縣三義鄉
#    368 = 苖栗縣西湖鄉
#    369 = 苖栗縣卓蘭鎮
#    400 = 台中市中區
#    401 = 台中市東區
#    402 = 台中市南區
#    403 = 台中市西區
#    404 = 台中市北區
#    406 = 台中市北屯區
#    407 = 台中市西屯區
#    408 = 台中市南屯區
#    411 = 台中市太平區
#    412 = 台中市大里區
#    413 = 台中市霧峰區
#    414 = 台中市烏日區
#    420 = 台中市豐原區
#    421 = 台中市后里區
#    422 = 台中市石岡區
#    423 = 台中市東勢區
#    424 = 台中市和平區
#    426 = 台中市新社區
#    427 = 台中市潭子區
#    428 = 台中市大雅區
#    429 = 台中市神岡區
#    432 = 台中市大肚區
#    433 = 台中市沙鹿區
#    434 = 台中市龍井區
#    435 = 台中市梧棲區
#    436 = 台中市清水區
#    437 = 台中市大甲區
#    438 = 台中市外埔區
#    439 = 台中市大安區
#    500 = 彰化縣彰化市
#    502 = 彰化縣芬園鄉
#    503 = 彰化縣花壇鄉
#    504 = 彰化縣秀水鄉
#    505 = 彰化縣鹿港鎮
#    506 = 彰化縣福興鄉
#    507 = 彰化縣線西鄉
#    508 = 彰化縣和美鎮
#    509 = 彰化縣伸港鄉
#    510 = 彰化縣員林鎮
#    511 = 彰化縣社頭鄉
#    512 = 彰化縣永靖鄉
#    513 = 彰化縣埔心鄉
#    514 = 彰化縣溪湖鎮
#    515 = 彰化縣大村鄉
#    516 = 彰化縣埔鹽鄉
#    520 = 彰化縣田中鎮
#    521 = 彰化縣北斗鎮
#    522 = 彰化縣田尾鄉
#    523 = 彰化縣埤頭鄉
#    524 = 彰化縣溪州鄉
#    525 = 彰化縣竹塘鄉
#    526 = 彰化縣二林鎮
#    527 = 彰化縣大城鄉
#    528 = 彰化縣芳苑鄉
#    530 = 彰化縣二水鄉
#    540 = 南投縣南投市
#    541 = 南投縣中寮鄉
#    542 = 南投縣草屯鎮
#    544 = 南投縣國姓鄉
#    545 = 南投縣埔里鎮
#    546 = 南投縣仁愛鄉
#    551 = 南投縣名間鄉
#    552 = 南投縣集集鎮
#    553 = 南投縣水里鄉
#    555 = 南投縣魚池鄉
#    556 = 南投縣信義鄉
#    557 = 南投縣竹山鎮
#    558 = 南投縣鹿谷鄉
#    600 = 嘉義市
#    602 = 嘉義縣番路鄉
#    603 = 嘉義縣梅山鄉
#    604 = 嘉義縣竹崎鄉
#    605 = 嘉義縣阿里山鄉
#    606 = 嘉義縣中埔鄉
#    607 = 嘉義縣大埔鄉
#    608 = 嘉義縣水上鄉
#    611 = 嘉義縣鹿草鄉
#    612 = 嘉義縣太保市
#    613 = 嘉義縣朴子市
#    614 = 嘉義縣東石鄉
#    615 = 嘉義縣六腳鄉
#    616 = 嘉義縣新港鄉
#    621 = 嘉義縣民雄鄉
#    622 = 嘉義縣大林鎮
#    623 = 嘉義縣溪口鄉
#    624 = 嘉義縣義竹鄉
#    625 = 嘉義縣布袋鎮
#    630 = 雲林縣斗南鎮
#    631 = 雲林縣大埤鄉
#    632 = 雲林縣虎尾鎮
#    633 = 雲林縣土庫鎮
#    634 = 雲林縣褒忠鄉
#    635 = 雲林縣東勢鄉
#    636 = 雲林縣臺西鄉
#    637 = 雲林縣崙背鄉
#    638 = 雲林縣麥寮鄉
#    640 = 雲林縣斗六市
#    643 = 雲林縣林內鄉
#    646 = 雲林縣古坑鄉
#    647 = 雲林縣莿桐鄉
#    648 = 雲林縣西螺鎮
#    649 = 雲林縣二崙鄉
#    651 = 雲林縣北港鎮
#    652 = 雲林縣水林鄉
#    653 = 雲林縣口湖鄉
#    654 = 雲林縣四湖鄉
#    655 = 雲林縣元長鄉
#    700 = 臺南市中西區
#    701 = 臺南市東區
#    702 = 臺南市南區
#    704 = 臺南市北區
#    708 = 臺南市安平區
#    709 = 臺南市安南區
#    710 = 臺南市永康區
#    711 = 臺南市歸仁區
#    712 = 臺南市新化區
#    713 = 臺南市左鎮區
#    714 = 臺南市玉井區
#    715 = 臺南市楠西區
#    716 = 臺南市南化區
#    717 = 臺南市仁德區
#    718 = 臺南市關廟區
#    719 = 臺南市龍崎區
#    720 = 臺南市官田區
#    721 = 臺南市麻豆區
#    722 = 臺南市佳里區
#    723 = 臺南市西港區
#    724 = 臺南市七股區
#    725 = 臺南市將軍區
#    726 = 臺南市學甲區
#    727 = 臺南市北門區
#    730 = 臺南市新營區
#    731 = 臺南市後壁區
#    732 = 臺南市白河區
#    733 = 臺南市東山區
#    734 = 臺南市六甲區
#    735 = 臺南市下營區
#    736 = 臺南市柳營區
#    737 = 臺南市鹽水區
#    741 = 臺南市善化區
#    742 = 臺南市大內區
#    743 = 臺南市山上區
#    744 = 臺南市新市區
#    745 = 臺南市安定區
#    800 = 高雄市新興區
#    801 = 高雄市前金區
#    802 = 高雄市苓雅區
#    803 = 高雄市鹽埕區
#    804 = 高雄市鼓山區
#    805 = 高雄市旗津區
#    806 = 高雄市前鎮區
#    807 = 高雄市三民區
#    811 = 高雄市楠梓區
#    812 = 高雄市小港區
#    813 = 高雄市左營區
#    814 = 高雄市仁武區
#    815 = 高雄市大社區
#    820 = 高雄市岡山區
#    821 = 高雄市路竹區
#    822 = 高雄市阿蓮區
#    823 = 高雄市田寮區
#    824 = 高雄市燕巢區
#    825 = 高雄市橋頭區
#    826 = 高雄市梓官區
#    827 = 高雄市彌陀區
#    828 = 高雄市永安區
#    829 = 高雄市湖內區
#    830 = 高雄市鳳山區
#    831 = 高雄市大寮區
#    832 = 高雄市林園區
#    833 = 高雄市鳥松區
#    840 = 高雄市大樹區
#    842 = 高雄市旗山區
#    843 = 高雄市美濃區
#    844 = 高雄市六龜區
#    845 = 高雄市內門區
#    846 = 高雄市杉林區
#    847 = 高雄市甲仙區
#    848 = 高雄市桃源區
#    849 = 高雄市三民區
#    851 = 高雄市那瑪夏區
#    852 = 高雄市茄萣區
#    880 = 澎湖縣馬公市
#    881 = 澎湖縣西嶼鄉
#    882 = 澎湖縣望安鄉
#    883 = 澎湖縣七美鄉
#    884 = 澎湖縣白沙鄉
#    885 = 澎湖縣湖西鄉
#    900 = 屏東縣屏東市
#    901 = 屏東縣三地門
#    902 = 屏東縣霧臺鄉
#    903 = 屏東縣瑪家鄉
#    904 = 屏東縣九如鄉
#    905 = 屏東縣里港鄉
#    906 = 屏東縣高樹鄉
#    907 = 屏東縣鹽埔鄉
#    908 = 屏東縣長治鄉
#    909 = 屏東縣麟洛鄉
#    911 = 屏東縣竹田鄉
#    912 = 屏東縣內埔鄉
#    913 = 屏東縣萬丹鄉
#    920 = 屏東縣潮州鎮
#    921 = 屏東縣泰武鄉
#    922 = 屏東縣來義鄉
#    923 = 屏東縣萬巒鄉
#    924 = 屏東縣嵌頂鄉
#    925 = 屏東縣新埤鄉
#    926 = 屏東縣南州鄉
#    927 = 屏東縣林邊鄉
#    928 = 屏東縣東港鄉
#    929 = 屏東縣琉球鄉
#    931 = 屏東縣佳冬鄉
#    932 = 屏東縣新園鄉
#    940 = 屏東縣枋寮鄉
#    941 = 屏東縣枋山鄉
#    942 = 屏東縣春日鄉
#    943 = 屏東縣獅子鄉
#    944 = 屏東縣車城鄉
#    945 = 屏東縣牡丹鄉
#    946 = 屏東縣恆春鎮
#    947 = 屏東縣滿洲鄉
#    950 = 臺東縣臺東市
#    951 = 臺東縣綠島鄉
#    952 = 臺東縣蘭嶼鄉
#    953 = 臺東縣延平鄉
#    954 = 臺東縣卑南鄉
#    955 = 臺東縣鹿野鄉
#    956 = 臺東縣關山鎮
#    957 = 臺東縣海端鄉
#    958 = 臺東縣池上鄉
#    959 = 臺東縣東河鄉
#    961 = 臺東縣成功鎮
#    962 = 臺東縣長濱鄉
#    963 = 臺東縣太麻里鄉
#    964 = 臺東縣金峰鄉
#    965 = 臺東縣大武鄉
#    966 = 臺東縣達仁鄉
#    970 = 花蓮縣花蓮市
#    971 = 花蓮縣新城鄉
#    972 = 花蓮縣秀林鄉
#    973 = 花蓮縣吉安鄉
#    974 = 花蓮縣壽豐鄉
#    975 = 花蓮縣鳳林鎮
#    976 = 花蓮縣光復鄉
#    977 = 花蓮縣豐濱鄉
#    978 = 花蓮縣瑞穗鄉
#    979 = 花蓮縣萬榮鄉
#    981 = 花蓮縣玉里鎮
#    982 = 花蓮縣卓溪鄉
#    983 = 花蓮縣富里鄉
# ------------------------------
# zip
# 326.0    45
# 807.0    45
# 820.0    44
# 940.0    40
# 843.0    39
#          ..
# 403.0    17
# 613.0    17
# 432.0    16
# 243.0    16
# 238.0    12
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# ## Find Common Labels Across All Years
#
# Identify variable labels (meanings) that appear in ALL survey years, regardless of variable name.

# %%
# Get all labels for each year
label_sets = {year: set(label_to_vars[year].keys()) for year in sorted(datasets.keys())}

# Find labels that exist in all years
common_labels = set.intersection(*label_sets.values())

print(f"Total labels appearing in ALL years: {len(common_labels)}")
print(f"\nFirst 20 common labels:")
print("="*70)
for i, label in enumerate(sorted(common_labels)[:20]):
    print(f"{i+1:3d}. {label}")
# Out:
# Total labels appearing in ALL years: 1
#
# First 20 common labels:
# ======================================================================
#   1. qtype 問卷別

# %% [markdown]
# ## Create Variable Mapping Across Years
#
# For each common label, show which variable name represents it in each year.

# %%
# Create mapping: label -> {year: variable_name}
label_mappings = {}

for label in common_labels:
    label_mappings[label] = {}
    for year in sorted(datasets.keys()):
        if label in label_to_vars[year]:
            label_mappings[label][year] = label_to_vars[year][label]

# Display sample mappings
print("Sample Variable Mappings (first 10 common concepts):")
print("="*80)
for i, (label, year_vars) in enumerate(sorted(label_mappings.items())[:10]):
    print(f"\n{i+1}. {label}")
    for year in sorted(year_vars.keys()):
        print(f"   {year}: {year_vars[year]}")

# %% [markdown]
# ## Check Data Completeness for Common Labels
#
# Assess missing data rates for variables representing each common concept.

# %%
# Calculate missing data for each common label across years
label_completeness = []

for label in sorted(common_labels):
    row = {'Label': label}
    missing_rates = []
    
    for year in sorted(datasets.keys()):
        var_name = label_mappings[label][year]
        missing_pct = (datasets[year][var_name].isna().sum() / len(datasets[year])) * 100
        row[str(year)] = f"{missing_pct:.1f}%"
        missing_rates.append(missing_pct)
    
    row['Max_Missing'] = max(missing_rates)
    label_completeness.append(row)

completeness_df = pd.DataFrame(label_completeness)

print("\nMissing Data Percentage by Year (first 20 variables):")
print("="*100)
display_cols = ['Label'] + [str(y) for y in sorted(datasets.keys())] + ['Max_Missing']
print(completeness_df[display_cols].head(20).to_string(index=False))

# %% [markdown]
# ## Identify High-Quality Variables for Visualization
#
# Filter concepts with < 10% missing data across all years and are suitable for time-series visualization.

# %%
# Find high-quality variables (< 10% missing)
high_quality_labels = []

for label in common_labels:
    max_missing = 0
    for year in sorted(datasets.keys()):
        var_name = label_mappings[label][year]
        missing_pct = (datasets[year][var_name].isna().sum() / len(datasets[year])) * 100
        max_missing = max(max_missing, missing_pct)
    
    if max_missing < 10:
        high_quality_labels.append(label)

print(f"High-quality concepts (< 10% missing in all years): {len(high_quality_labels)}")
print("\nRecommended concepts for time-series visualization:")
print("="*70)
for i, label in enumerate(sorted(high_quality_labels)[:30], 1):
    # Show variable names across years
    vars_str = " -> ".join([label_mappings[label][year] for year in sorted(datasets.keys())])
    print(f"{i:3d}. {label}")
    print(f"     Variables: {vars_str}")

# %% [markdown]
# ## Analyze Variable Types and Value Ranges
#
# Understand what types of data these common concepts contain.

# %%
# Analyze high-quality variables
variable_analysis = []

for label in sorted(high_quality_labels)[:20]:  # First 20 for detailed analysis
    # Get variable from first year as reference
    first_year = sorted(datasets.keys())[0]
    var_name = label_mappings[label][first_year]
    
    # Get basic stats
    data_sample = datasets[first_year][var_name].dropna()
    
    analysis = {
        'Label': label,
        'Type': str(data_sample.dtype),
        'Unique_Values': data_sample.nunique(),
        'Sample_Values': str(sorted(data_sample.unique())[:5])
    }
    
    variable_analysis.append(analysis)

analysis_df = pd.DataFrame(variable_analysis)
print("\nVariable Type Analysis (first 20 high-quality concepts):")
print("="*100)
print(analysis_df.to_string(index=False))

# %% [markdown]
# ## Sample Analysis: Time-Series for a Specific Concept
#
# Demonstrate how a concept's values change over the 30-year period.

# %%
# Pick a high-quality label for demonstration
if high_quality_labels:
    sample_label = sorted(high_quality_labels)[0]
    print(f"Time-Series Analysis for: {sample_label}")
    print("="*70)
    
    for year in sorted(datasets.keys()):
        var_name = label_mappings[sample_label][year]
        print(f"\n{year} (variable: {var_name}):")
        value_counts = datasets[year][var_name].value_counts().head(10)
        print(value_counts)
        
        # Check if there are value labels
        if var_name in metadata[year].variable_value_labels:
            value_labels = metadata[year].variable_value_labels[var_name]
            print("\nValue Labels:")
            for val, label in list(value_labels.items())[:10]:
                print(f"  {val}: {label}")
else:
    print("No high-quality variables found for sample analysis")

# %% [markdown]
# ## Find Labels Present in Most Years (Not Necessarily All)
#
# Some important concepts may exist in 5-6 years but not all 7.

# %%
# Count how many years each label appears in
label_year_counts = defaultdict(list)

for year in sorted(datasets.keys()):
    for label in label_to_vars[year].keys():
        label_year_counts[label].append(year)

# Find labels in at least 5 years
frequent_labels = {label: years for label, years in label_year_counts.items() 
                   if len(years) >= 5}

print(f"Labels appearing in at least 5 out of 7 years: {len(frequent_labels)}")
print("\nSample of labels in 5-6 years (first 20):")
print("="*70)

count = 0
for label, years in sorted(frequent_labels.items()):
    if len(years) < 7 and count < 20:  # Show only those NOT in all years
        count += 1
        print(f"{count}. {label}")
        print(f"   Years: {years}")

# %% [markdown]
# ## Export Comprehensive Summary for Visualization

# %%
import json

# Create comprehensive summary
summary = {
    'survey_years': list(sorted(datasets.keys())),
    'total_common_labels': len(common_labels),
    'high_quality_labels': len(high_quality_labels),
    'label_mappings': {},  # {label: {year: var_name}}
    'high_quality_concepts': [],
    'frequent_labels_5plus_years': len(frequent_labels)
}

# Add complete mappings for high-quality labels
for label in high_quality_labels:
    summary['label_mappings'][label] = label_mappings[label]
    
    # Add detailed info
    first_year = sorted(datasets.keys())[0]
    var_name = label_mappings[label][first_year]
    
    concept_info = {
        'label': label,
        'variables_by_year': label_mappings[label],
        'data_type': str(datasets[first_year][var_name].dtype),
        'unique_values': int(datasets[first_year][var_name].nunique())
    }
    
    summary['high_quality_concepts'].append(concept_info)

# Save summary
with open('tscs_variable_summary.json', 'w', encoding='utf-8') as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

print("✓ Summary exported to: tscs_variable_summary.json")
print(f"\nSummary Statistics:")
print(f"  - Survey years: {summary['survey_years']}")
print(f"  - Common labels (all 7 years): {summary['total_common_labels']}")
print(f"  - High-quality labels (< 10% missing): {summary['high_quality_labels']}")
print(f"  - Labels in 5+ years: {summary['frequent_labels_5plus_years']}")

# %% [markdown]
# ## Create Detailed Report of Top Concepts

# %%
# Create a detailed report for easy review
print("="*80)
print("TOP 30 CONCEPTS FOR TIME-SERIES VISUALIZATION")
print("="*80)

for i, label in enumerate(sorted(high_quality_labels)[:30], 1):
    print(f"\n{i}. {label}")
    print("-" * 70)
    
    # Show variable mapping
    print("Variable names by year:")
    for year in sorted(datasets.keys()):
        var_name = label_mappings[label][year]
        n_valid = datasets[year][var_name].notna().sum()
        n_total = len(datasets[year])
        print(f"  {year}: {var_name:15s} ({n_valid}/{n_total} valid responses)")
    
    # Show sample values from first year
    first_year = sorted(datasets.keys())[0]
    var_name = label_mappings[label][first_year]
    unique_vals = datasets[first_year][var_name].nunique()
    print(f"\nUnique values: {unique_vals}")
    
    # Show value distribution from first year
    print("\nValue distribution (first year):")
    print(datasets[first_year][var_name].value_counts().head())

# %% [markdown]
# ## Conclusion
#
# This analysis identified variables **by their semantic meaning (labels)** that exist across all TSCS survey years (1992-2022). Even though variable names may differ across years (e.g., v_26 in 1992 vs v_32 in 1997), if they measure the same concept (e.g., "subjective wealth"), they are tracked together.
#
# **Key Findings**:
# - Identified common concepts that can be tracked over 30 years
# - Created mappings showing which variable represents each concept in each year
# - Filtered for data quality to ensure reliable visualization
# - Prepared structured data for d3.js time-series visualization
#
# **Next Steps**:
# 1. Review the top concepts and select those most interesting for visualization
# 2. Integrate selected concepts with the Taiwan geographical map
# 3. Create interactive time-series animations showing change over 30 years
